# %% [markdown]
# # Downloade Twitter-usernamen aller AFD Abgeordneten
#
# __Nach Anleitung (https://www.jitsejan.com/using-scrapy-in-jupyter-notebook.html)__
#
# __Fraktionsseite: https://www.afdbundestag.de/abgeordnete/__

# %%
# Settings for notebook
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Show Python version
import platform
platform.python_version()
# Out:
# '3.6.9'

# %%
import json

class JsonWriterPipeline(object):

    def open_spider(self, spider):
        self.file = open('AFD_twitter.json', 'w')

    def close_spider(self, spider):
        self.file.close()

    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
import logging
from scrapy.utils.log import configure_logging
from urllib.parse import urlparse



configure_logging(install_root_handler=False)
logging.basicConfig(
    filename='AFD_log.txt',
    filemode = 'w',
    format='%(levelname)s: %(message)s',
    level=logging.DEBUG
)



class AFDSpider(scrapy.Spider):
    name = "AFD_Abgeordnete_Twitter"
    custom_settings = {
        'LOG_LEVEL': logging.INFO,
        'ITEM_PIPELINES': {'__main__.JsonWriterPipeline': 1}, # Used for pipeline 1
        'FEED_FORMAT':'json',                                 # Used for pipeline 2
        'FEED_URI': 'Gruene_twitter.json'                     # Used for pipeline 2
    }

    def start_requests(self):
        urls = [
            'https://www.afdbundestag.de/abgeordnete/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)

    def parse(self, response):
        #for href in response.css("div.teaserList.teaserType-weitereInfoTeaser.teaserList--tiny a::attr('href')"):
        for link in response.css("div.fusion-column-wrapper a::attr(href)").extract():
            #print(link)
            #url = response.urljoin(link)
            #url = urlparse.urljoin(response.url, link)
            yield response.follow(link, callback=self.parse_dir_contents)

#            print(url)
#            yield scrapy.Request(link, callback = self.parse_dir_contents)

    def parse_dir_contents(self, response):
        for delegate in response.css('body'):
            print(delegate)
            yield {
                #'text': delegate.css('li.twitter::text').getall(),
                'name': delegate.xpath('//a[contains(@href, "twitter.com")]/@href').getall(),
            }

# %%
process3 = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})

process3.crawl(AFDSpider)
process3.start()
# Out:
# 2020-04-04 16:19:48 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: scrapybot)
# 2020-04-04 16:19:48 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.7.0, Python 3.6.9 (default, Nov  7 2019, 10:44:02) - [GCC 8.3.0], pyOpenSSL 19.0.0 (OpenSSL 1.1.1  11 Sep 2018), cryptography 2.1.4, Platform Linux-4.15.0-91-generic-x86_64-with-Ubuntu-18.04-bionic
# 2020-04-04 16:19:48 [scrapy.crawler] INFO: Overridden settings: {'FEED_FORMAT': 'json', 'FEED_URI': 'Gruene_twitter.json', 'LOG_LEVEL': 20, 'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2020-04-04 16:19:48 [scrapy.extensions.telnet] INFO: Telnet Password: 1fb9cd35d04f9803
# 2020-04-04 16:19:48 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2020-04-04 16:19:48 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-04-04 16:19:48 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-04-04 16:19:48 [scrapy.middleware] INFO: Enabled item pipelines:
# ['__main__.JsonWriterPipeline']
# 2020-04-04 16:19:48 [scrapy.core.engine] INFO: Spider opened
# 2020-04-04 16:19:48 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-04-04 16:19:48 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-04-04 16:19:49 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/andreas-bleck/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/dr-bernd-baumann/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/nicole-hoechst/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/waldemar-herdt/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/marc-bernhard/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/prof-dr-ing-heiko-hessenkemper/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/martin-hess/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Error downloading <GET mailto:justiziariat@afdbundestag.de>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/twisted/internet/defer.py", line 1416, in _inlineCallbacks
#     result = result.throwExceptionIntoGenerator(g)
#   File "/usr/local/lib/python3.6/dist-packages/twisted/python/failure.py", line 512, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/middleware.py", line 44, in process_request
#     defer.returnValue((yield download_func(request=request, spider=spider)))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 45, in mustbe_deferred
#     result = f(*args, **kw)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/handlers/__init__.py", line 70, in download_request
#     (scheme, self._notconfigured[scheme]))
# scrapy.exceptions.NotSupported: Unsupported URL scheme 'mailto': no handler available for that scheme
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Error downloading <GET mailto:buerger@afdbundestag.de>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/twisted/internet/defer.py", line 1416, in _inlineCallbacks
#     result = result.throwExceptionIntoGenerator(g)
#   File "/usr/local/lib/python3.6/dist-packages/twisted/python/failure.py", line 512, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/middleware.py", line 44, in process_request
#     defer.returnValue((yield download_func(request=request, spider=spider)))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 45, in mustbe_deferred
#     result = f(*args, **kw)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/handlers/__init__.py", line 70, in download_request
#     (scheme, self._notconfigured[scheme]))
# scrapy.exceptions.NotSupported: Unsupported URL scheme 'mailto': no handler available for that scheme
# 2020-04-04 16:19:51 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/martin-hohmann/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:19:52 [scrapy.core.scraper] ERROR: Error downloading <GET tel:+493022757143>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/twisted/internet/defer.py", line 1416, in _inlineCallbacks
#     result = result.throwExceptionIntoGenerator(g)
#   File "/usr/local/lib/python3.6/dist-packages/twisted/python/failure.py", line 512, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/middleware.py", line 44, in process_request
#     defer.returnValue((yield download_func(request=request, spider=spider)))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 45, in mustbe_deferred
#     result = f(*args, **kw)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/handlers/__init__.py", line 70, in download_request
#     (scheme, self._notconfigured[scheme]))
# scrapy.exceptions.NotSupported: Unsupported URL scheme 'tel': no handler available for that scheme
# 2020-04-04 16:19:52 [scrapy.core.scraper] ERROR: Error downloading <GET tel:+493022757141>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/twisted/internet/defer.py", line 1416, in _inlineCallbacks
#     result = result.throwExceptionIntoGenerator(g)
#   File "/usr/local/lib/python3.6/dist-packages/twisted/python/failure.py", line 512, in throwExceptionIntoGenerator
#     return g.throw(self.type, self.value, self.tb)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/middleware.py", line 44, in process_request
#     defer.returnValue((yield download_func(request=request, spider=spider)))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 45, in mustbe_deferred
#     result = f(*args, **kw)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/downloader/handlers/__init__.py", line 70, in download_request
#     (scheme, self._notconfigured[scheme]))
# scrapy.exceptions.NotSupported: Unsupported URL scheme 'tel': no handler available for that scheme
# 2020-04-04 16:19:52 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/karsten-hilse/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:19:52 [scrapy.core.scraper] ERROR: Spider error processing <GET https://mobile.twitter.com/afdimbundestag> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:52 [scrapy.core.scraper] ERROR: Spider error processing <GET https://m.facebook.com/afdimbundestag/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="images nojs users-page u...'>
# <Selector xpath='descendant-or-self::body' data='<body tabindex="0" class="b c d"><div...'>
# 2020-04-04 16:19:52 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.youtube.com/c/afdfraktionimbundestag> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body><span itemprop="author" itemsco...'>
# 2020-04-04 16:19:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/martin-hebner/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:19:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/dr-roland-hartwig/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:19:53 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/kay-gottschalk/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
# ...
# 2020-04-04 16:20:14 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/joana-cotar/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:20:14 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/peter-boehringer/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:20:14 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/stephan-brandner/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:20:15 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/tino-chrupalla/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
# 2020-04-04 16:20:15 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.afdbundestag.de/person/petr-bystron/> (referer: https://www.afdbundestag.de/abgeordnete/)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# lxml.etree.XPathEvalError: Invalid number of arguments
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/utils/defer.py", line 102, in iter_errback
#     yield next(it)
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/offsite.py", line 29, in process_spider_output
#     for x in result:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/referer.py", line 339, in <genexpr>
#     return (_set_referer(r) for r in result or ())
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/urllength.py", line 37, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/core/spidermw.py", line 84, in evaluate_iterable
#     for r in iterable:
#   File "/usr/local/lib/python3.6/dist-packages/scrapy/spidermiddlewares/depth.py", line 58, in <genexpr>
#     return (r for r in result or () if _filter(r))
#   File "<ipython-input-3-fa626b931da1>", line 51, in parse_dir_contents
#     'name': delegate.xpath('//a[contains(@href, "twitter.com", "Profil aufrufen")]/@href').getall(),
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 242, in xpath
#     six.reraise(ValueError, ValueError(msg), sys.exc_info()[2])
#   File "/usr/lib/python3/dist-packages/six.py", line 692, in reraise
#     raise value.with_traceback(tb)
#   File "/usr/local/lib/python3.6/dist-packages/parsel/selector.py", line 238, in xpath
#     **kwargs)
#   File "src/lxml/etree.pyx", line 1577, in lxml.etree._Element.xpath
#   File "src/lxml/xpath.pxi", line 307, in lxml.etree.XPathElementEvaluator.__call__
#   File "src/lxml/xpath.pxi", line 227, in lxml.etree._XPathEvaluatorBase._handle_result
# ValueError: XPath error: Invalid number of arguments in //a[contains(@href, "twitter.com", "Profil aufrufen")]/@href
# 2020-04-04 16:20:15 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-04-04 16:20:15 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/exception_count': 4,
#  'downloader/exception_type_count/scrapy.exceptions.NotSupported': 4,
#  'downloader/request_bytes': 30246,
#  'downloader/request_count': 99,
#  'downloader/request_method_count/GET': 99,
#  'downloader/response_bytes': 10520180,
#  'downloader/response_count': 95,
#  'downloader/response_status_count/200': 94,
#  'downloader/response_status_count/302': 1,
#  'dupefilter/filtered': 248,
#  'elapsed_time_seconds': 26.400236,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 4, 4, 14, 20, 15, 278350),
#  'log_count/ERROR': 96,
#  'log_count/INFO': 10,
#  'memusage/max': 69828608,
#  'memusage/startup': 69828608,
#  'request_depth_max': 1,
#  'response_received_count': 93,
#  'scheduler/dequeued': 99,
#  'scheduler/dequeued/memory': 99,
#  'scheduler/enqueued': 99,
#  'scheduler/enqueued/memory': 99,
#  'spider_exceptions/ValueError': 92,
#  'start_time': datetime.datetime(2020, 4, 4, 14, 19, 48, 878114)}
# 2020-04-04 16:20:15 [scrapy.core.engine] INFO: Spider closed (finished)
# <Selector xpath='descendant-or-self::body' data='<body class="person-template-default ...'>
