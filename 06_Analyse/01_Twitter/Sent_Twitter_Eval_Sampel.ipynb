# %% [markdown]
# # Twitter Klassifizierung nach TUWien (GermEval2018)
# Das Training und die eigentliche Klassifizierung wird im Python File 'Twitter_Sent_Analyse_TUWien_auto' durchgeführt. In diesem File findet sich:
# * Die Verbesserung und Analyse der Trainingsdaten und Ergebnisse
# * Zusammenstellung des Endgültigen Trainingssatzes und Evaluierung (Accuracy, Precission, Recall, F1)

# %%
Path = '/home/lisa/Darmstadt/Master Arbeit/06_Analyse/01_Twitter'

# %% [markdown]
# ### Verhältnis von OFFENSE Tweets zu Rest - Erstellung eigener TrainingsDaten
# Hinweis: manche der hier verwendeten .txt files wurden der Übersicht halber gelöscht. Der folgende Code dient daher primär zum nachvollziehen, als zum direkten nachbilden.

# %%
import pickle, gensim, numpy as np
import csv
import pandas as pd
import datetime

## Lade Datensätze und erstelle DataFrames
from utilities import get_train_data, get_test_data, Tokenizer, find_subtoken
more_train = get_train_data(Path + '/Evaluierung_Sampling/more_train.csv')
train = {'Text': more_train[0], 'Label': more_train[1]} 
df_more_train = pd.DataFrame(train)

GermEval_train = get_train_data(Path + '/Evaluierung_Sampling/germeval2018.training_all_8541.txt')
train_GermEval = {'Text': GermEval_train[0], 'Label': GermEval_train[1]} 
df_GermEval_train = pd.DataFrame(train_GermEval)

compare_old_new = pickle.load(open(Path+"/Evaluierung_Sampling/compare_old_new_label.p", "rb" ))
#old_all = pickle.load(open(Path + 'sent_df_Wien', "rb" ))

# %%
## Vergleich der Verhältnisse von OFFENSE Tweets zum Rest
perc_OFFENSE_train = (len(df_more_train[df_more_train['Label'] == 'OFFENSE']) / len(df_more_train)) * 100
perc_OFFENSE_GermEval = (len(df_GermEval_train[df_GermEval_train['Label'] == 'OFFENSE']) / len(df_GermEval_train)) * 100
perc_OFFENSE_all = (len(old_all[old_all['predict'] == 'OFFENSE']) / len(old_all['predict'])) * 100

print('Im aktuellen more_training file liegt der Anteil von OFFENSE Tweets bei: ' + str(perc_OFFENSE_train))
print('Im GermEval Trainings Satz liegt der Anteil von OFFENSE Tweets bei: ' + str(perc_OFFENSE_GermEval))
print('Im anfänglichen gesamtDatensatz lag nach dem Labeling mit GermEval der Anteil von OFFENSE Tweets bei: ' + str(perc_OFFENSE_all))
# Out:
# Im aktuellen more_training file liegt der Anteil von OFFENSE Tweets bei: 50.706214689265536
# Im GermEval Trainings Satz liegt der Anteil von OFFENSE Tweets bei: 33.8367872614448
# Im anfänglichen gesamtDatensatz lag nach dem Labeling mit GermEval der Anteil von OFFENSE Tweets bei: 6.96534218199701

# %% [markdown]
# ### Laden der gelabelten Datensätze und zusammenfügen

# %%
PICKLE_FOLDER_PATH_old = '/home/lisa/Darmstadt/Master Arbeit/06_Analyse/pickle_TU_Wien/compare/'
PICKLE_FOLDER_PATH_new = '/home/lisa/Darmstadt/Master Arbeit/06_Analyse/pickle_TU_Wien/'

# Die csv files 'old' und 'new' werden im jeweiligen Verzeichnis erstellt:

with open(PICKLE_FOLDER_PATH_old + 'old.txt') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        old = row

with open(PICKLE_FOLDER_PATH_new + 'new.txt') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
        new = row

        
# Jeder gelabelte DataFrame wird aufgerufen und in einem Dictionary gespeichert
Twitter_test_new = {}
Twitter_test_old = {}

for file in new:
    Twitter_test_new[file] = pickle.load(open(PICKLE_FOLDER_PATH_new + file, "rb" ))

for file in old:
    Twitter_test_old[file] = pickle.load(open(PICKLE_FOLDER_PATH_old + file, "rb" ))

# %%
# Die DataFrames werden aus den Dictionarys erstellt

Twitter_comp_new = pd.concat(Twitter_test_new, axis=0)
Twitter_comp_old = pd.concat(Twitter_test_old, axis=0)

Twitter_comp_old.loc[:,('Woche')] = Twitter_comp_old.created_at_datetime.dt.strftime('%y-w%U')
# Nur die Teile des alten DataFrames werden betrachtet, die im gleichen Zeitraum sind wie der neue
Twitter_comp_old = Twitter_comp_old.loc[(Twitter_comp_old['Woche'] == '20-w03') |
                                       (Twitter_comp_old['Woche'] == '20-w06')|
                                       (Twitter_comp_old['Woche'] == '20-w08')|
                                       (Twitter_comp_old['Woche'] == '20-w09')|
                                       (Twitter_comp_old['Woche'] == '20-w15')|
                                       (Twitter_comp_old['Woche'] == '20-w19')|
                                       (Twitter_comp_old['Woche'] == '20-w23')|
                                       (Twitter_comp_old['Woche'] == '20-w25')|
                                       (Twitter_comp_old['Woche'] == '20-w27')]

# %% [markdown]
# ### Erstelle DataFrame zum Vergleich der "alten" und "neuen" gelabelten Sätze

# %%
twit_comp_new = []
twit_comp_old = []
twit_text_new = []
twit_text_old = []

for i in range(0, len(Twitter_comp_new)):
    if Twitter_comp_new['full_text_processed'][i] in set(Twitter_comp_old['full_text_processed']):
        twit_comp_new.append(Twitter_comp_new['predict'][i])
        twit_comp_old.append(Twitter_comp_old[Twitter_comp_old['full_text_processed'] == Twitter_comp_new['full_text_processed'][i]]['predict'].values[0])
        twit_text_new.append(Twitter_comp_new['full_text_processed'][i])
        twit_text_old.append(Twitter_comp_old[Twitter_comp_old['full_text_processed'] == Twitter_comp_new['full_text_processed'][i]]['full_text_processed'].values[0])
    else:
        print('Keine Überlappung bei: ' + str(i))
# Out:
# Keine Überlappung bei: 3028
# Keine Überlappung bei: 3029
# Keine Überlappung bei: 3030
# Keine Überlappung bei: 3031
# Keine Überlappung bei: 3032
# Keine Überlappung bei: 3033
# Keine Überlappung bei: 3034
# Keine Überlappung bei: 3035
# Keine Überlappung bei: 3036
# Keine Überlappung bei: 3037
# Keine Überlappung bei: 3038
# Keine Überlappung bei: 3039
# Keine Überlappung bei: 3040
# Keine Überlappung bei: 3041
# Keine Überlappung bei: 3042
# Keine Überlappung bei: 3045
# Keine Überlappung bei: 3046
# Keine Überlappung bei: 3047
# Keine Überlappung bei: 3048
# Keine Überlappung bei: 3049
# Keine Überlappung bei: 3050
# Keine Überlappung bei: 3051
# Keine Überlappung bei: 3052
# Keine Überlappung bei: 3053
# Keine Überlappung bei: 3054
# Keine Überlappung bei: 3058
# Keine Überlappung bei: 3059
# Keine Überlappung bei: 3060
# Keine Überlappung bei: 3061
# Keine Überlappung bei: 3062
# Keine Überlappung bei: 3063
# Keine Überlappung bei: 3064
# Keine Überlappung bei: 3065
# Keine Überlappung bei: 3066
# Keine Überlappung bei: 3395
# Keine Überlappung bei: 3396
# Keine Überlappung bei: 3397
# Keine Überlappung bei: 3398
# Keine Überlappung bei: 3399
# Keine Überlappung bei: 3400
# Keine Überlappung bei: 3401
# Keine Überlappung bei: 3402
# Keine Überlappung bei: 3403
# Keine Überlappung bei: 3404
# Keine Überlappung bei: 3405
# Keine Überlappung bei: 3406
# Keine Überlappung bei: 3407
# Keine Überlappung bei: 3408
# Keine Überlappung bei: 3409
# Keine Überlappung bei: 3410
# Keine Überlappung bei: 3411
# Keine Überlappung bei: 3412
# Keine Überlappung bei: 3413
# Keine Überlappung bei: 3414
# Keine Überlappung bei: 3415
# Keine Überlappung bei: 3416
# Keine Überlappung bei: 3417
# Keine Überlappung bei: 3418
# Keine Überlappung bei: 3419
# Keine Überlappung bei: 3420
# Keine Überlappung bei: 3421
# Keine Überlappung bei: 3422
# Keine Überlappung bei: 3423
# Keine Überlappung bei: 3424
# Keine Überlappung bei: 3425
# Keine Überlappung bei: 3426
# Keine Überlappung bei: 3427
# Keine Überlappung bei: 3428
# Keine Überlappung bei: 3429
# Keine Überlappung bei: 3430
# Keine Überlappung bei: 3431
# Keine Überlappung bei: 3433
# Keine Überlappung bei: 3434
# Keine Überlappung bei: 3435
# Keine Überlappung bei: 3436
# Keine Überlappung bei: 3437
# Keine Überlappung bei: 3438
# Keine Überlappung bei: 3439
# Keine Überlappung bei: 3440
# Keine Überlappung bei: 3441
# Keine Überlappung bei: 3442
# Keine Überlappung bei: 3443
# Keine Überlappung bei: 3444
# Keine Überlappung bei: 3445
# Keine Überlappung bei: 3446
# Keine Überlappung bei: 3447
# Keine Überlappung bei: 3448
# Keine Überlappung bei: 3449
# Keine Überlappung bei: 3450
# Keine Überlappung bei: 3451
# Keine Überlappung bei: 3452
# Keine Überlappung bei: 3453
# Keine Überlappung bei: 3454
# Keine Überlappung bei: 3455
# Keine Überlappung bei: 3456
# Keine Überlappung bei: 3457
# Keine Überlappung bei: 3458
# Keine Überlappung bei: 3459
# Keine Überlappung bei: 3460
# Keine Überlappung bei: 3461
# Keine Überlappung bei: 3462
# Keine Überlappung bei: 3463
# Keine Überlappung bei: 3464
# Keine Überlappung bei: 3465
# Keine Überlappung bei: 3466
# Keine Überlappung bei: 3467
# Keine Überlappung bei: 3468
# Keine Überlappung bei: 3469
# Keine Überlappung bei: 3470
# Keine Überlappung bei: 3471
# Keine Überlappung bei: 3472
# Keine Überlappung bei: 3473
# Keine Überlappung bei: 3474
# Keine Überlappung bei: 3475
# Keine Überlappung bei: 3476
# Keine Überlappung bei: 3477
# Keine Überlappung bei: 3478
# Keine Überlappung bei: 3479
# Keine Überlappung bei: 3480
# Keine Überlappung bei: 3481
# Keine Überlappung bei: 3482
# Keine Überlappung bei: 3483
# Keine Überlappung bei: 3484
# Keine Überlappung bei: 3485
# Keine Überlappung bei: 3486
# Keine Überlappung bei: 3487
# Keine Überlappung bei: 3488
# Keine Überlappung bei: 3489
# Keine Überlappung bei: 3490
# Keine Überlappung bei: 3491
# Keine Überlappung bei: 3492
# Keine Überlappung bei: 3493
# Keine Überlappung bei: 3494
# Keine Überlappung bei: 3495
# Keine Überlappung bei: 3496
# Keine Überlappung bei: 3497
# Keine Überlappung bei: 3498
# Keine Überlappung bei: 3499
# Keine Überlappung bei: 3500
# Keine Überlappung bei: 3501
# Keine Überlappung bei: 3502
# Keine Überlappung bei: 3503
# Keine Überlappung bei: 3504
# Keine Überlappung bei: 3505
# Keine Überlappung bei: 3506
# Keine Überlappung bei: 3507
# Keine Überlappung bei: 3508
# Keine Überlappung bei: 3509
# Keine Überlappung bei: 3510
# Keine Überlappung bei: 3511
# Keine Überlappung bei: 3512
# Keine Überlappung bei: 3513
# Keine Überlappung bei: 3514
# Keine Überlappung bei: 3515
# Keine Überlappung bei: 3516
# Keine Überlappung bei: 3517
# Keine Überlappung bei: 3518
# Keine Überlappung bei: 3519
# Keine Überlappung bei: 3520
# Keine Überlappung bei: 3521
# Keine Überlappung bei: 3522
# Keine Überlappung bei: 3523
# Keine Überlappung bei: 3524
# Keine Überlappung bei: 3525
# Keine Überlappung bei: 3526
# Keine Überlappung bei: 3527
# Keine Überlappung bei: 3528
# Keine Überlappung bei: 3529
# Keine Überlappung bei: 3530
# Keine Überlappung bei: 3531
# Keine Überlappung bei: 3532
# Keine Überlappung bei: 3533
# Keine Überlappung bei: 3534
# Keine Überlappung bei: 3535
# Keine Überlappung bei: 3536
# Keine Überlappung bei: 3537
# Keine Überlappung bei: 3538
# Keine Überlappung bei: 3539
# Keine Überlappung bei: 3540
# Keine Überlappung bei: 3541
# Keine Überlappung bei: 3542
# Keine Überlappung bei: 3543
# Keine Überlappung bei: 3544
# Keine Überlappung bei: 3545
# Keine Überlappung bei: 3546
# Keine Überlappung bei: 3547
# Keine Überlappung bei: 3548
# Keine Überlappung bei: 3549
# Keine Überlappung bei: 3550
# Keine Überlappung bei: 3551
# Keine Überlappung bei: 3552
# Keine Überlappung bei: 3553
# Keine Überlappung bei: 3554
# Keine Überlappung bei: 3555
# Keine Überlappung bei: 3556
# Keine Überlappung bei: 3557
# Keine Überlappung bei: 3558
# Keine Überlappung bei: 3559
# Keine Überlappung bei: 3560
# Keine Überlappung bei: 3561
# Keine Überlappung bei: 3562
# Keine Überlappung bei: 3563
# Keine Überlappung bei: 3564
# Keine Überlappung bei: 3565
# Keine Überlappung bei: 3566
# Keine Überlappung bei: 3567
# Keine Überlappung bei: 3568
# Keine Überlappung bei: 3569
# Keine Überlappung bei: 3570
# Keine Überlappung bei: 3571
# Keine Überlappung bei: 3572
# Keine Überlappung bei: 3573
# Keine Überlappung bei: 3574
# Keine Überlappung bei: 3575
# Keine Überlappung bei: 3576
# Keine Überlappung bei: 3577
# Keine Überlappung bei: 3578
# Keine Überlappung bei: 3579
# Keine Überlappung bei: 3580
# Keine Überlappung bei: 3581
# Keine Überlappung bei: 3582
# Keine Überlappung bei: 3583
# Keine Überlappung bei: 3584
# Keine Überlappung bei: 3585
# Keine Überlappung bei: 3586
# Keine Überlappung bei: 3587
# Keine Überlappung bei: 3588
# Keine Überlappung bei: 3589
# Keine Überlappung bei: 3590
# Keine Überlappung bei: 3591
# Keine Überlappung bei: 3592
# Keine Überlappung bei: 3593
# Keine Überlappung bei: 3594
# Keine Überlappung bei: 3595
# Keine Überlappung bei: 3596
# Keine Überlappung bei: 3597
# Keine Überlappung bei: 3598
# Keine Überlappung bei: 3599
# Keine Überlappung bei: 3600
# Keine Überlappung bei: 3601
# Keine Überlappung bei: 3602
# Keine Überlappung bei: 3603
# Keine Überlappung bei: 3604
# Keine Überlappung bei: 3605
# Keine Überlappung bei: 3606
# Keine Überlappung bei: 3607
# Keine Überlappung bei: 3608
# Keine Überlappung bei: 3609
# Keine Überlappung bei: 3610
# Keine Überlappung bei: 3611
# Keine Überlappung bei: 3612
# Keine Überlappung bei: 3613
# Keine Überlappung bei: 3614
# Keine Überlappung bei: 3615
# Keine Überlappung bei: 3616
# Keine Überlappung bei: 3617
# Keine Überlappung bei: 3618
# Keine Überlappung bei: 3619
# Keine Überlappung bei: 3620
# Keine Überlappung bei: 3621
# Keine Überlappung bei: 3622
# Keine Überlappung bei: 3623
# Keine Überlappung bei: 3624
# Keine Überlappung bei: 3625
# Keine Überlappung bei: 3626
# Keine Überlappung bei: 3627
# Keine Überlappung bei: 3628
# Keine Überlappung bei: 3629
# Keine Überlappung bei: 3630
# Keine Überlappung bei: 3631
# Keine Überlappung bei: 3632
# Keine Überlappung bei: 3633
# Keine Überlappung bei: 3634
# Keine Überlappung bei: 3635
# Keine Überlappung bei: 3636
# Keine Überlappung bei: 3637
# Keine Überlappung bei: 3638
# Keine Überlappung bei: 3639
# Keine Überlappung bei: 3640
# Keine Überlappung bei: 3641
# Keine Überlappung bei: 3642
# Keine Überlappung bei: 3643
# Keine Überlappung bei: 3644
# Keine Überlappung bei: 3645
# Keine Überlappung bei: 3646
# Keine Überlappung bei: 3647
# Keine Überlappung bei: 3648
# Keine Überlappung bei: 3649
# Keine Überlappung bei: 3650
# Keine Überlappung bei: 3651
# Keine Überlappung bei: 3652
# Keine Überlappung bei: 3653
# Keine Überlappung bei: 3654
# Keine Überlappung bei: 3655
# Keine Überlappung bei: 3656
# Keine Überlappung bei: 3657
# Keine Überlappung bei: 3658
# Keine Überlappung bei: 3659
# Keine Überlappung bei: 3660
# Keine Überlappung bei: 3661
# Keine Überlappung bei: 3662
# Keine Überlappung bei: 3663
# Keine Überlappung bei: 3664
# Keine Überlappung bei: 3665
# Keine Überlappung bei: 3666
# Keine Überlappung bei: 3667
# Keine Überlappung bei: 3668
# Keine Überlappung bei: 3669
# Keine Überlappung bei: 3670
# Keine Überlappung bei: 3671
# Keine Überlappung bei: 3672
# Keine Überlappung bei: 3673
# Keine Überlappung bei: 3674
# Keine Überlappung bei: 3675
# Keine Überlappung bei: 3676
# Keine Überlappung bei: 3677
# Keine Überlappung bei: 3678
# Keine Überlappung bei: 3679
# Keine Überlappung bei: 3680
# Keine Überlappung bei: 3681
# Keine Überlappung bei: 3682
# Keine Überlappung bei: 3683
# Keine Überlappung bei: 3684
# Keine Überlappung bei: 3685
# Keine Überlappung bei: 3686
# Keine Überlappung bei: 3687
# Keine Überlappung bei: 3688
# Keine Überlappung bei: 3689
# Keine Überlappung bei: 3690
# Keine Überlappung bei: 3691
# Keine Überlappung bei: 3692
# Keine Überlappung bei: 3693
# Keine Überlappung bei: 3694
# Keine Überlappung bei: 3695
# Keine Überlappung bei: 3696
# Keine Überlappung bei: 3697
# Keine Überlappung bei: 3698
# Keine Überlappung bei: 3699
# Keine Überlappung bei: 3700
# Keine Überlappung bei: 3701
# Keine Überlappung bei: 3702
# Keine Überlappung bei: 3703
# Keine Überlappung bei: 3704
# Keine Überlappung bei: 3705
# Keine Überlappung bei: 3706
# Keine Überlappung bei: 3707
# Keine Überlappung bei: 3708
# Keine Überlappung bei: 3709
# Keine Überlappung bei: 3710
# Keine Überlappung bei: 3711
# Keine Überlappung bei: 3712
# Keine Überlappung bei: 3713
# Keine Überlappung bei: 3714
# Keine Überlappung bei: 3715
# Keine Überlappung bei: 3716
# Keine Überlappung bei: 3717
# Keine Überlappung bei: 3718
# Keine Überlappung bei: 3719
# Keine Überlappung bei: 3720
# Keine Überlappung bei: 3721
# Keine Überlappung bei: 3722
# Keine Überlappung bei: 3723
# Keine Überlappung bei: 3724
# Keine Überlappung bei: 3725
# Keine Überlappung bei: 3726
# Keine Überlappung bei: 3727
# Keine Überlappung bei: 3728
# Keine Überlappung bei: 3729
# Keine Überlappung bei: 3730
# Keine Überlappung bei: 3731
# Keine Überlappung bei: 3732
# Keine Überlappung bei: 3733
# Keine Überlappung bei: 3734
# Keine Überlappung bei: 3735
# Keine Überlappung bei: 3736
# Keine Überlappung bei: 3737
# Keine Überlappung bei: 3738
# Keine Überlappung bei: 3739
# Keine Überlappung bei: 3740
# Keine Überlappung bei: 3741
# Keine Überlappung bei: 3742
# Keine Überlappung bei: 3743
# Keine Überlappung bei: 3744
# Keine Überlappung bei: 3745
# Keine Überlappung bei: 3746
# Keine Überlappung bei: 3747
# Keine Überlappung bei: 3748
# Keine Überlappung bei: 3749
# Keine Überlappung bei: 3750
# Keine Überlappung bei: 3751
# Keine Überlappung bei: 3752
# Keine Überlappung bei: 3753
# Keine Überlappung bei: 3754
# Keine Überlappung bei: 3755
# Keine Überlappung bei: 3756
# Keine Überlappung bei: 3757
# Keine Überlappung bei: 3758
# Keine Überlappung bei: 3759
# Keine Überlappung bei: 3760
# Keine Überlappung bei: 3761
# Keine Überlappung bei: 3762
# Keine Überlappung bei: 3763
# Keine Überlappung bei: 3764
# Keine Überlappung bei: 3765
# Keine Überlappung bei: 3766
# Keine Überlappung bei: 3767
# Keine Überlappung bei: 3768
# Keine Überlappung bei: 3769
# Keine Überlappung bei: 3770
# Keine Überlappung bei: 3771
# Keine Überlappung bei: 3772
# Keine Überlappung bei: 3773
# Keine Überlappung bei: 3774
# Keine Überlappung bei: 3775
# Keine Überlappung bei: 3776
# Keine Überlappung bei: 3777
# Keine Überlappung bei: 3778
# Keine Überlappung bei: 3779
# Keine Überlappung bei: 3780
# Keine Überlappung bei: 3781
# Keine Überlappung bei: 3782
# Keine Überlappung bei: 3783
# Keine Überlappung bei: 3784
# Keine Überlappung bei: 3785
# Keine Überlappung bei: 3786
# Keine Überlappung bei: 3787
# Keine Überlappung bei: 3788
# Keine Überlappung bei: 3789
# Keine Überlappung bei: 3790
# Keine Überlappung bei: 3791
# Keine Überlappung bei: 3792
# Keine Überlappung bei: 3793
# Keine Überlappung bei: 3794
# Keine Überlappung bei: 3795
# Keine Überlappung bei: 3796
# Keine Überlappung bei: 3797
# Keine Überlappung bei: 3798
# Keine Überlappung bei: 3799
# Keine Überlappung bei: 3800
# Keine Überlappung bei: 3801
# Keine Überlappung bei: 3802
# Keine Überlappung bei: 3803
# Keine Überlappung bei: 3804
# Keine Überlappung bei: 3805
# Keine Überlappung bei: 3806
# Keine Überlappung bei: 3807
# Keine Überlappung bei: 3808
# Keine Überlappung bei: 3809
# Keine Überlappung bei: 3810
# Keine Überlappung bei: 3811
# Keine Überlappung bei: 3812
# Keine Überlappung bei: 3813
# Keine Überlappung bei: 3814
# Keine Überlappung bei: 3815
# Keine Überlappung bei: 3816
# Keine Überlappung bei: 3817
# Keine Überlappung bei: 3818
# Keine Überlappung bei: 3819
# Keine Überlappung bei: 3820
# Keine Überlappung bei: 3821
# Keine Überlappung bei: 3822
# Keine Überlappung bei: 3823
# Keine Überlappung bei: 3824
# Keine Überlappung bei: 3825
# Keine Überlappung bei: 3826
# Keine Überlappung bei: 3827
# Keine Überlappung bei: 3828
# Keine Überlappung bei: 3829
# Keine Überlappung bei: 3830
# Keine Überlappung bei: 3831
# Keine Überlappung bei: 3832
# Keine Überlappung bei: 3833
# Keine Überlappung bei: 3834
# Keine Überlappung bei: 3835
# Keine Überlappung bei: 3836
# Keine Überlappung bei: 3837
# Keine Überlappung bei: 3838
# Keine Überlappung bei: 3839
# Keine Überlappung bei: 3840
# Keine Überlappung bei: 3841
# Keine Überlappung bei: 3842
# Keine Überlappung bei: 3843
# Keine Überlappung bei: 3844
# Keine Überlappung bei: 3845
# Keine Überlappung bei: 3846
# Keine Überlappung bei: 3847
# Keine Überlappung bei: 3848
# Keine Überlappung bei: 3849
# Keine Überlappung bei: 3850
# Keine Überlappung bei: 3851
# Keine Überlappung bei: 3852
# Keine Überlappung bei: 3853
# Keine Überlappung bei: 3854
# Keine Überlappung bei: 3855
# Keine Überlappung bei: 3856
# Keine Überlappung bei: 3857
# Keine Überlappung bei: 3858
# Keine Überlappung bei: 3859
# Keine Überlappung bei: 3860
# Keine Überlappung bei: 3861
# Keine Überlappung bei: 3862
# Keine Überlappung bei: 3863
# Keine Überlappung bei: 3864
# Keine Überlappung bei: 3865
# Keine Überlappung bei: 3866
# Keine Überlappung bei: 3867
# Keine Überlappung bei: 3868
# Keine Überlappung bei: 3869
# Keine Überlappung bei: 3870
# Keine Überlappung bei: 3871
# Keine Überlappung bei: 3872
# Keine Überlappung bei: 3873
# Keine Überlappung bei: 3874
# Keine Überlappung bei: 3875
# Keine Überlappung bei: 3876
# Keine Überlappung bei: 3877
# Keine Überlappung bei: 3878
# Keine Überlappung bei: 3879
# Keine Überlappung bei: 3880
# Keine Überlappung bei: 3881
# Keine Überlappung bei: 3882
# Keine Überlappung bei: 3883
# Keine Überlappung bei: 3884
# Keine Überlappung bei: 3885
# Keine Überlappung bei: 3886
# Keine Überlappung bei: 3887
# Keine Überlappung bei: 3888
# Keine Überlappung bei: 3889
# Keine Überlappung bei: 3890
# Keine Überlappung bei: 3891
# Keine Überlappung bei: 3892
# Keine Überlappung bei: 3893
# Keine Überlappung bei: 3894
# Keine Überlappung bei: 3895
# Keine Überlappung bei: 3896
# Keine Überlappung bei: 3897
# Keine Überlappung bei: 3898
# Keine Überlappung bei: 3899
# Keine Überlappung bei: 3900
# Keine Überlappung bei: 3901
# Keine Überlappung bei: 3902
# Keine Überlappung bei: 3903
# Keine Überlappung bei: 3904
# Keine Überlappung bei: 3905
# Keine Überlappung bei: 3906
# Keine Überlappung bei: 3907
# Keine Überlappung bei: 3908
# Keine Überlappung bei: 3909
# Keine Überlappung bei: 3910
# Keine Überlappung bei: 3911
# Keine Überlappung bei: 3912
# Keine Überlappung bei: 3913
# Keine Überlappung bei: 3914
# Keine Überlappung bei: 3915
# Keine Überlappung bei: 3916
# Keine Überlappung bei: 3917
# Keine Überlappung bei: 3918
# Keine Überlappung bei: 3919
# Keine Überlappung bei: 3920
# Keine Überlappung bei: 3921
# Keine Überlappung bei: 3922
# Keine Überlappung bei: 3923
# Keine Überlappung bei: 3924
# Keine Überlappung bei: 3925
# Keine Überlappung bei: 3926
# Keine Überlappung bei: 3927
# Keine Überlappung bei: 3928
# Keine Überlappung bei: 3929
# Keine Überlappung bei: 3930
# Keine Überlappung bei: 3931
# Keine Überlappung bei: 3932
# Keine Überlappung bei: 3933
# Keine Überlappung bei: 3934
# Keine Überlappung bei: 3935
# Keine Überlappung bei: 3936
# Keine Überlappung bei: 3937
# Keine Überlappung bei: 3938
# Keine Überlappung bei: 3939
# Keine Überlappung bei: 3940
# Keine Überlappung bei: 3941
# Keine Überlappung bei: 3942
# Keine Überlappung bei: 3943
# Keine Überlappung bei: 3944
# Keine Überlappung bei: 3945
# Keine Überlappung bei: 3946
# Keine Überlappung bei: 3947
# Keine Überlappung bei: 3948
# Keine Überlappung bei: 3949
# Keine Überlappung bei: 3950
# Keine Überlappung bei: 3951
# Keine Überlappung bei: 3952
# Keine Überlappung bei: 3954
# Keine Überlappung bei: 3955
# Keine Überlappung bei: 3956
# Keine Überlappung bei: 3957
# Keine Überlappung bei: 3958
# Keine Überlappung bei: 3959
# Keine Überlappung bei: 3960
# Keine Überlappung bei: 3961
# Keine Überlappung bei: 3962
# Keine Überlappung bei: 3963
# Keine Überlappung bei: 3964
# Keine Überlappung bei: 3965
# Keine Überlappung bei: 3966
# Keine Überlappung bei: 3967
# Keine Überlappung bei: 3968
# Keine Überlappung bei: 3969
# Keine Überlappung bei: 3970
# Keine Überlappung bei: 3971
# Keine Überlappung bei: 3972
# Keine Überlappung bei: 3973
# Keine Überlappung bei: 3974
# Keine Überlappung bei: 3975
# Keine Überlappung bei: 3976
# Keine Überlappung bei: 3977
# Keine Überlappung bei: 3978
# Keine Überlappung bei: 3979
# Keine Überlappung bei: 3980
# Keine Überlappung bei: 3981
# Keine Überlappung bei: 3982
# Keine Überlappung bei: 3983
# Keine Überlappung bei: 3984
# Keine Überlappung bei: 3985
# Keine Überlappung bei: 3986
# Keine Überlappung bei: 3987
# Keine Überlappung bei: 3988
# Keine Überlappung bei: 3989
# Keine Überlappung bei: 3990
# Keine Überlappung bei: 3991
# Keine Überlappung bei: 3992
# Keine Überlappung bei: 3993
# Keine Überlappung bei: 3995
# Keine Überlappung bei: 3996
# Keine Überlappung bei: 3997
# Keine Überlappung bei: 3998
# Keine Überlappung bei: 3999
# Keine Überlappung bei: 4000
# Keine Überlappung bei: 4001
# Keine Überlappung bei: 4002
# Keine Überlappung bei: 4003
# Keine Überlappung bei: 4004
# Keine Überlappung bei: 4005
# Keine Überlappung bei: 4006
# Keine Überlappung bei: 4007
# Keine Überlappung bei: 4008
# Keine Überlappung bei: 4009
# Keine Überlappung bei: 4010
# Keine Überlappung bei: 4011
# Keine Überlappung bei: 4012
# Keine Überlappung bei: 4013
# Keine Überlappung bei: 4014
# Keine Überlappung bei: 4015
# Keine Überlappung bei: 4016
# Keine Überlappung bei: 4017
# Keine Überlappung bei: 4018
# Keine Überlappung bei: 4019
# Keine Überlappung bei: 4020
# Keine Überlappung bei: 4021
# Keine Überlappung bei: 4022
# Keine Überlappung bei: 4023
# Keine Überlappung bei: 4024
# Keine Überlappung bei: 4025
# Keine Überlappung bei: 4026
# Keine Überlappung bei: 4027
# Keine Überlappung bei: 4028
# Keine Überlappung bei: 4029
# Keine Überlappung bei: 4030
# Keine Überlappung bei: 4031
# Keine Überlappung bei: 4032
# Keine Überlappung bei: 4033
# Keine Überlappung bei: 4034
# Keine Überlappung bei: 4035
# Keine Überlappung bei: 4036
# Keine Überlappung bei: 4037
# Keine Überlappung bei: 4038
# Keine Überlappung bei: 4039
# Keine Überlappung bei: 4040
# Keine Überlappung bei: 4041
# Keine Überlappung bei: 4042
# Keine Überlappung bei: 4043
# Keine Überlappung bei: 4044
# Keine Überlappung bei: 4045
# Keine Überlappung bei: 4046
# Keine Überlappung bei: 4047
# Keine Überlappung bei: 4048
# Keine Überlappung bei: 4049
# Keine Überlappung bei: 4050
# Keine Überlappung bei: 4051
# Keine Überlappung bei: 4052
# Keine Überlappung bei: 4053
# Keine Überlappung bei: 4054
# Keine Überlappung bei: 4055
# Keine Überlappung bei: 4056
# Keine Überlappung bei: 4057
# Keine Überlappung bei: 4058
# Keine Überlappung bei: 4059
# Keine Überlappung bei: 4060
# Keine Überlappung bei: 4061
# Keine Überlappung bei: 4062
# Keine Überlappung bei: 4063
# Keine Überlappung bei: 4064
# Keine Überlappung bei: 4065
# Keine Überlappung bei: 4066
# Keine Überlappung bei: 4067
# Keine Überlappung bei: 4068
# Keine Überlappung bei: 4069
# Keine Überlappung bei: 4070
# Keine Überlappung bei: 4071
# Keine Überlappung bei: 4072
# Keine Überlappung bei: 4073
# Keine Überlappung bei: 4074
# Keine Überlappung bei: 4075
# Keine Überlappung bei: 4076
# Keine Überlappung bei: 4077
# Keine Überlappung bei: 4078
# Keine Überlappung bei: 4079
# Keine Überlappung bei: 4080
# Keine Überlappung bei: 4081
# Keine Überlappung bei: 4082
# Keine Überlappung bei: 4083
# Keine Überlappung bei: 4084
# Keine Überlappung bei: 4085
# Keine Überlappung bei: 4086
# Keine Überlappung bei: 4087
# Keine Überlappung bei: 4088
# Keine Überlappung bei: 4089
# Keine Überlappung bei: 4090
# Keine Überlappung bei: 4091
# Keine Überlappung bei: 4092
# Keine Überlappung bei: 4093
# Keine Überlappung bei: 4094
# Keine Überlappung bei: 4095
# Keine Überlappung bei: 4096
# Keine Überlappung bei: 4097
# Keine Überlappung bei: 4098
# Keine Überlappung bei: 4099
# Keine Überlappung bei: 4100
# Keine Überlappung bei: 4101
# Keine Überlappung bei: 4102
# Keine Überlappung bei: 4103
# Keine Überlappung bei: 4104
# Keine Überlappung bei: 4105
# Keine Überlappung bei: 4106
# Keine Überlappung bei: 4107
# Keine Überlappung bei: 4108
# Keine Überlappung bei: 4109
# Keine Überlappung bei: 4110
# Keine Überlappung bei: 4111
# Keine Überlappung bei: 4112
# Keine Überlappung bei: 4113
# Keine Überlappung bei: 4114
# Keine Überlappung bei: 4115
# Keine Überlappung bei: 4116
# Keine Überlappung bei: 4117
# Keine Überlappung bei: 4118
# Keine Überlappung bei: 4119
# Keine Überlappung bei: 4120
# Keine Überlappung bei: 4121
# Keine Überlappung bei: 4122
# Keine Überlappung bei: 4123
# Keine Überlappung bei: 4124
# Keine Überlappung bei: 4125
# Keine Überlappung bei: 4126
# Keine Überlappung bei: 4127
# Keine Überlappung bei: 4128
# Keine Überlappung bei: 4129
# Keine Überlappung bei: 4130
# Keine Überlappung bei: 4131
# Keine Überlappung bei: 4132
# Keine Überlappung bei: 4133
# Keine Überlappung bei: 4134
# Keine Überlappung bei: 4135
# Keine Überlappung bei: 4136
# Keine Überlappung bei: 4137
# Keine Überlappung bei: 4138
# Keine Überlappung bei: 4139
# Keine Überlappung bei: 4140
# Keine Überlappung bei: 4141
# Keine Überlappung bei: 4142
# Keine Überlappung bei: 4143
# Keine Überlappung bei: 4144
# Keine Überlappung bei: 4145
# Keine Überlappung bei: 4146
# Keine Überlappung bei: 4147
# Keine Überlappung bei: 4148
# Keine Überlappung bei: 4149
# Keine Überlappung bei: 4150
# Keine Überlappung bei: 4151
# Keine Überlappung bei: 4152
# Keine Überlappung bei: 4153
# Keine Überlappung bei: 4154
# Keine Überlappung bei: 4155
# Keine Überlappung bei: 4156
# Keine Überlappung bei: 4157
# Keine Überlappung bei: 4158
# Keine Überlappung bei: 4159
# Keine Überlappung bei: 4160
# Keine Überlappung bei: 4161
# Keine Überlappung bei: 4162
# Keine Überlappung bei: 4163
# Keine Überlappung bei: 4164
# Keine Überlappung bei: 4165
# Keine Überlappung bei: 4166
# Keine Überlappung bei: 4167
# Keine Überlappung bei: 4168
# Keine Überlappung bei: 4169
# Keine Überlappung bei: 4170
# Keine Überlappung bei: 4171
# Keine Überlappung bei: 4172
# Keine Überlappung bei: 4173
# Keine Überlappung bei: 4174
# Keine Überlappung bei: 4175
# Keine Überlappung bei: 4176
# Keine Überlappung bei: 4177
# Keine Überlappung bei: 4178
# Keine Überlappung bei: 4179
# Keine Überlappung bei: 4180
# Keine Überlappung bei: 4181
# Keine Überlappung bei: 4182
# Keine Überlappung bei: 4183
# Keine Überlappung bei: 4184
# Keine Überlappung bei: 4185
# Keine Überlappung bei: 4186
# Keine Überlappung bei: 4187
# Keine Überlappung bei: 4188
# Keine Überlappung bei: 4189
# Keine Überlappung bei: 4190
# Keine Überlappung bei: 4191
# Keine Überlappung bei: 4192
# Keine Überlappung bei: 4193
# Keine Überlappung bei: 4194
# Keine Überlappung bei: 4195
# Keine Überlappung bei: 4196
# Keine Überlappung bei: 4197
# Keine Überlappung bei: 4198
# Keine Überlappung bei: 4199
# Keine Überlappung bei: 4200
# Keine Überlappung bei: 4201
# Keine Überlappung bei: 4202
# Keine Überlappung bei: 4203
# Keine Überlappung bei: 4204
# Keine Überlappung bei: 4205
# Keine Überlappung bei: 4206
# Keine Überlappung bei: 4207
# Keine Überlappung bei: 4208
# Keine Überlappung bei: 4209
# Keine Überlappung bei: 4210
# Keine Überlappung bei: 4211
# Keine Überlappung bei: 4212
# Keine Überlappung bei: 4213
# Keine Überlappung bei: 4214
# Keine Überlappung bei: 4215
# Keine Überlappung bei: 4216
# Keine Überlappung bei: 4217
# Keine Überlappung bei: 4218
# Keine Überlappung bei: 4219
# Keine Überlappung bei: 4220
# Keine Überlappung bei: 4221
# Keine Überlappung bei: 4222
# Keine Überlappung bei: 4223
# Keine Überlappung bei: 4224
# Keine Überlappung bei: 4225
# Keine Überlappung bei: 4226
# Keine Überlappung bei: 4227
# Keine Überlappung bei: 4228
# Keine Überlappung bei: 4229
# Keine Überlappung bei: 4230
# Keine Überlappung bei: 4231
# Keine Überlappung bei: 4232
# Keine Überlappung bei: 4233
# Keine Überlappung bei: 4234
# Keine Überlappung bei: 4235
# Keine Überlappung bei: 4236
# Keine Überlappung bei: 4237
# Keine Überlappung bei: 4238
# Keine Überlappung bei: 4239
# Keine Überlappung bei: 4240
# Keine Überlappung bei: 4241
# Keine Überlappung bei: 4242
# Keine Überlappung bei: 4243
# Keine Überlappung bei: 4244
# Keine Überlappung bei: 4245
# Keine Überlappung bei: 4246
# Keine Überlappung bei: 4247
# Keine Überlappung bei: 4248
# Keine Überlappung bei: 4249
# Keine Überlappung bei: 4250
# Keine Überlappung bei: 4251
# Keine Überlappung bei: 4252
# Keine Überlappung bei: 4253
# Keine Überlappung bei: 4254
# Keine Überlappung bei: 4255
# Keine Überlappung bei: 4256
# Keine Überlappung bei: 4257
# Keine Überlappung bei: 4258
# Keine Überlappung bei: 4259
# Keine Überlappung bei: 4260
# Keine Überlappung bei: 4261
# Keine Überlappung bei: 4262
# Keine Überlappung bei: 4263
# Keine Überlappung bei: 4264
# Keine Überlappung bei: 4265
# Keine Überlappung bei: 4266
# Keine Überlappung bei: 4267
# Keine Überlappung bei: 4268
# Keine Überlappung bei: 4269
# Keine Überlappung bei: 4270
# Keine Überlappung bei: 4271
# Keine Überlappung bei: 4272
# Keine Überlappung bei: 4273
# Keine Überlappung bei: 4274
# Keine Überlappung bei: 4275
# Keine Überlappung bei: 4276
# Keine Überlappung bei: 4277
# Keine Überlappung bei: 4278
# Keine Überlappung bei: 4279
# Keine Überlappung bei: 4280
# Keine Überlappung bei: 4281
# Keine Überlappung bei: 4282
# Keine Überlappung bei: 4283
# Keine Überlappung bei: 4284
# Keine Überlappung bei: 4285
# Keine Überlappung bei: 4286
# Keine Überlappung bei: 4287
# Keine Überlappung bei: 4288
# Keine Überlappung bei: 4289
# Keine Überlappung bei: 4290
# Keine Überlappung bei: 4291
# Keine Überlappung bei: 4292
# Keine Überlappung bei: 4293
# Keine Überlappung bei: 4294
# Keine Überlappung bei: 4295
# Keine Überlappung bei: 4296
# Keine Überlappung bei: 4297
# Keine Überlappung bei: 4298
# Keine Überlappung bei: 4299
# Keine Überlappung bei: 4300
# Keine Überlappung bei: 4301
# Keine Überlappung bei: 4302
# Keine Überlappung bei: 4303
# Keine Überlappung bei: 4304
# Keine Überlappung bei: 4305
# Keine Überlappung bei: 4306
# Keine Überlappung bei: 4307
# Keine Überlappung bei: 4308
# Keine Überlappung bei: 4309
# Keine Überlappung bei: 4310
# Keine Überlappung bei: 4311
# Keine Überlappung bei: 4312
# Keine Überlappung bei: 4313
# Keine Überlappung bei: 4314
# Keine Überlappung bei: 4315
# Keine Überlappung bei: 4316
# Keine Überlappung bei: 4317
# Keine Überlappung bei: 4318
# Keine Überlappung bei: 4319
# Keine Überlappung bei: 4320
# Keine Überlappung bei: 4321
# Keine Überlappung bei: 4322
# Keine Überlappung bei: 4323
# Keine Überlappung bei: 4324
# Keine Überlappung bei: 4325
# Keine Überlappung bei: 4326
# Keine Überlappung bei: 4327
# Keine Überlappung bei: 4328
# Keine Überlappung bei: 4329
# Keine Überlappung bei: 4330
# Keine Überlappung bei: 4331
# Keine Überlappung bei: 4332
# Keine Überlappung bei: 4333
# Keine Überlappung bei: 4334
# Keine Überlappung bei: 4335
# Keine Überlappung bei: 4336
# Keine Überlappung bei: 4337
# Keine Überlappung bei: 4338
# Keine Überlappung bei: 4339
# Keine Überlappung bei: 4340
# Keine Überlappung bei: 4341
# Keine Überlappung bei: 4342
# Keine Überlappung bei: 4343
# Keine Überlappung bei: 4344
# Keine Überlappung bei: 4345
# Keine Überlappung bei: 4346
# Keine Überlappung bei: 4347
# Keine Überlappung bei: 4348
# Keine Überlappung bei: 4349
# Keine Überlappung bei: 4350
# Keine Überlappung bei: 4351
# Keine Überlappung bei: 4352
# Keine Überlappung bei: 4353
# Keine Überlappung bei: 4354
# Keine Überlappung bei: 4355
# Keine Überlappung bei: 4356
# Keine Überlappung bei: 4357
# Keine Überlappung bei: 4358
# Keine Überlappung bei: 4359
# Keine Überlappung bei: 4360
# Keine Überlappung bei: 4361
# Keine Überlappung bei: 4362
# Keine Überlappung bei: 4363
# Keine Überlappung bei: 4364
# Keine Überlappung bei: 4365
# Keine Überlappung bei: 4366
# Keine Überlappung bei: 4367
# Keine Überlappung bei: 4368
# Keine Überlappung bei: 4369
# Keine Überlappung bei: 4370
# Keine Überlappung bei: 4371
# Keine Überlappung bei: 4372
# Keine Überlappung bei: 4373
# Keine Überlappung bei: 4374
# Keine Überlappung bei: 4375
# Keine Überlappung bei: 4376
# Keine Überlappung bei: 4377
# Keine Überlappung bei: 4378
# Keine Überlappung bei: 4379
# Keine Überlappung bei: 4380
# Keine Überlappung bei: 4381
# Keine Überlappung bei: 4382
# Keine Überlappung bei: 4383
# Keine Überlappung bei: 4384
# Keine Überlappung bei: 4385
# Keine Überlappung bei: 4386
# Keine Überlappung bei: 4387
# Keine Überlappung bei: 4388
# Keine Überlappung bei: 4389
# Keine Überlappung bei: 4390
# Keine Überlappung bei: 4391
# Keine Überlappung bei: 4392
# Keine Überlappung bei: 4393
# Keine Überlappung bei: 4394
# Keine Überlappung bei: 4395
# Keine Überlappung bei: 4396
# Keine Überlappung bei: 4397
# Keine Überlappung bei: 4398
# Keine Überlappung bei: 4399
# Keine Überlappung bei: 4400
# Keine Überlappung bei: 4401
# Keine Überlappung bei: 4402
# Keine Überlappung bei: 4403
# Keine Überlappung bei: 4404
# Keine Überlappung bei: 4405
# Keine Überlappung bei: 4406
# Keine Überlappung bei: 4407
# Keine Überlappung bei: 4408
# Keine Überlappung bei: 4409
# Keine Überlappung bei: 4410
# Keine Überlappung bei: 4411
# Keine Überlappung bei: 4412
# Keine Überlappung bei: 4413
# Keine Überlappung bei: 4414
# Keine Überlappung bei: 4415
# Keine Überlappung bei: 4416
# Keine Überlappung bei: 4417
# Keine Überlappung bei: 4418
# Keine Überlappung bei: 4419
# Keine Überlappung bei: 4420
# Keine Überlappung bei: 4421
# Keine Überlappung bei: 4422
# Keine Überlappung bei: 4423
# Keine Überlappung bei: 4424
# Keine Überlappung bei: 4425
# Keine Überlappung bei: 4426
# Keine Überlappung bei: 4427
# Keine Überlappung bei: 4428
# Keine Überlappung bei: 4429
# Keine Überlappung bei: 4430
# Keine Überlappung bei: 4431
# Keine Überlappung bei: 4432
# Keine Überlappung bei: 4433
# Keine Überlappung bei: 4434
# Keine Überlappung bei: 4435
# Keine Überlappung bei: 4436
# Keine Überlappung bei: 4437
# Keine Überlappung bei: 4438
# Keine Überlappung bei: 4439
# Keine Überlappung bei: 4440
# Keine Überlappung bei: 4441
# Keine Überlappung bei: 4442
# Keine Überlappung bei: 4443
# Keine Überlappung bei: 4444
# Keine Überlappung bei: 4445
# Keine Überlappung bei: 4446
# Keine Überlappung bei: 4447
# Keine Überlappung bei: 4448
# Keine Überlappung bei: 4449
# Keine Überlappung bei: 4450
# Keine Überlappung bei: 4451
# Keine Überlappung bei: 4452
# Keine Überlappung bei: 4453
# Keine Überlappung bei: 4454
# Keine Überlappung bei: 4455
# Keine Überlappung bei: 4456
# Keine Überlappung bei: 4457
# Keine Überlappung bei: 4458
# Keine Überlappung bei: 4459
# Keine Überlappung bei: 4460
# Keine Überlappung bei: 4461
# Keine Überlappung bei: 4462
# Keine Überlappung bei: 4463
# Keine Überlappung bei: 4464
# Keine Überlappung bei: 4465
# Keine Überlappung bei: 4466
# Keine Überlappung bei: 4467
# Keine Überlappung bei: 4468
# Keine Überlappung bei: 4469
# Keine Überlappung bei: 4470
# Keine Überlappung bei: 4471
# Keine Überlappung bei: 4472
# Keine Überlappung bei: 4473
# Keine Überlappung bei: 4474
# Keine Überlappung bei: 4475
# Keine Überlappung bei: 4476
# Keine Überlappung bei: 4477
# Keine Überlappung bei: 4478
# Keine Überlappung bei: 4479
# Keine Überlappung bei: 4480
# Keine Überlappung bei: 4481
# Keine Überlappung bei: 4482
# Keine Überlappung bei: 4483
# Keine Überlappung bei: 4484
# Keine Überlappung bei: 4485
# Keine Überlappung bei: 4486
# Keine Überlappung bei: 4487
# Keine Überlappung bei: 4488
# Keine Überlappung bei: 4489
# Keine Überlappung bei: 4490
# Keine Überlappung bei: 4491
# Keine Überlappung bei: 4492
# Keine Überlappung bei: 4493
# Keine Überlappung bei: 4494
# Keine Überlappung bei: 4495
# Keine Überlappung bei: 4496
# Keine Überlappung bei: 4497
# Keine Überlappung bei: 4498
# Keine Überlappung bei: 4499
# Keine Überlappung bei: 4500
# Keine Überlappung bei: 4501
# Keine Überlappung bei: 4502
# Keine Überlappung bei: 4503
# Keine Überlappung bei: 4504
# Keine Überlappung bei: 4505
# Keine Überlappung bei: 4506
# Keine Überlappung bei: 4507
# Keine Überlappung bei: 4508
# Keine Überlappung bei: 4509
# Keine Überlappung bei: 4510
# Keine Überlappung bei: 4511
# Keine Überlappung bei: 4512
# Keine Überlappung bei: 4513
# Keine Überlappung bei: 4514
# Keine Überlappung bei: 4515
# Keine Überlappung bei: 4516
# Keine Überlappung bei: 4517
# Keine Überlappung bei: 4518
# Keine Überlappung bei: 4519
# Keine Überlappung bei: 4520
# Keine Überlappung bei: 4521
# Keine Überlappung bei: 4522
# Keine Überlappung bei: 4523
# Keine Überlappung bei: 4525
# Keine Überlappung bei: 4526
# Keine Überlappung bei: 4527
# Keine Überlappung bei: 4529
# Keine Überlappung bei: 4530
# Keine Überlappung bei: 4531
# Keine Überlappung bei: 4532
# Keine Überlappung bei: 4533
# Keine Überlappung bei: 4534
# Keine Überlappung bei: 4535
# Keine Überlappung bei: 4536
# Keine Überlappung bei: 4537
# Keine Überlappung bei: 4538
# Keine Überlappung bei: 4539
# Keine Überlappung bei: 4540
# Keine Überlappung bei: 4541
# Keine Überlappung bei: 4542
# Keine Überlappung bei: 4543
# Keine Überlappung bei: 4544
# Keine Überlappung bei: 4545
# Keine Überlappung bei: 4546
# Keine Überlappung bei: 4547
# Keine Überlappung bei: 4548
# Keine Überlappung bei: 4549
# Keine Überlappung bei: 4550
# Keine Überlappung bei: 4551
# Keine Überlappung bei: 4552
# Keine Überlappung bei: 4553
# Keine Überlappung bei: 4554
# Keine Überlappung bei: 4555
# Keine Überlappung bei: 4556
# Keine Überlappung bei: 4557
# Keine Überlappung bei: 4558
# Keine Überlappung bei: 4559
# Keine Überlappung bei: 4560
# Keine Überlappung bei: 4561
# Keine Überlappung bei: 4562
# Keine Überlappung bei: 4563
# Keine Überlappung bei: 4564
# Keine Überlappung bei: 4565
# Keine Überlappung bei: 4566
# Keine Überlappung bei: 4567
# Keine Überlappung bei: 4568
# Keine Überlappung bei: 4569
# Keine Überlappung bei: 4570
# Keine Überlappung bei: 4571
# Keine Überlappung bei: 4572
# Keine Überlappung bei: 4573
# Keine Überlappung bei: 4574
# Keine Überlappung bei: 4575
# Keine Überlappung bei: 4576
# Keine Überlappung bei: 4577
# Keine Überlappung bei: 4578
# Keine Überlappung bei: 4579
# Keine Überlappung bei: 4580
# Keine Überlappung bei: 4581
# Keine Überlappung bei: 4582
# Keine Überlappung bei: 4583
# Keine Überlappung bei: 4584
# Keine Überlappung bei: 4585
# Keine Überlappung bei: 4586
# Keine Überlappung bei: 4587
# Keine Überlappung bei: 4588
# Keine Überlappung bei: 4589
# Keine Überlappung bei: 4590
# Keine Überlappung bei: 4591
# Keine Überlappung bei: 4592
# Keine Überlappung bei: 4593
# Keine Überlappung bei: 4594
# Keine Überlappung bei: 4595
# Keine Überlappung bei: 4596
# Keine Überlappung bei: 4597
# Keine Überlappung bei: 4598
# Keine Überlappung bei: 4599
# Keine Überlappung bei: 4600
# Keine Überlappung bei: 4601
# Keine Überlappung bei: 4602
# Keine Überlappung bei: 4603
# Keine Überlappung bei: 4604
# Keine Überlappung bei: 4605
# Keine Überlappung bei: 4606
# Keine Überlappung bei: 4607
# Keine Überlappung bei: 4608
# Keine Überlappung bei: 4609
# Keine Überlappung bei: 4610
# Keine Überlappung bei: 4611
# Keine Überlappung bei: 4612
# Keine Überlappung bei: 4613
# Keine Überlappung bei: 4614
# Keine Überlappung bei: 4615
# Keine Überlappung bei: 4616
# Keine Überlappung bei: 4617
# Keine Überlappung bei: 4618
# Keine Überlappung bei: 4619
# Keine Überlappung bei: 4620
# Keine Überlappung bei: 4621
# Keine Überlappung bei: 4622
# Keine Überlappung bei: 4623
# Keine Überlappung bei: 4624
# Keine Überlappung bei: 4625
# Keine Überlappung bei: 4626
# Keine Überlappung bei: 4627
# Keine Überlappung bei: 4628
# Keine Überlappung bei: 4629
# Keine Überlappung bei: 4630
# Keine Überlappung bei: 4631
# Keine Überlappung bei: 4632
# Keine Überlappung bei: 4633
# Keine Überlappung bei: 4634
# Keine Überlappung bei: 4635
# Keine Überlappung bei: 4636
# Keine Überlappung bei: 4637
# Keine Überlappung bei: 4638
# Keine Überlappung bei: 4639
# Keine Überlappung bei: 4640
# Keine Überlappung bei: 4641
# Keine Überlappung bei: 4642
# Keine Überlappung bei: 4643
# Keine Überlappung bei: 4644
# Keine Überlappung bei: 4645
# Keine Überlappung bei: 4646
# Keine Überlappung bei: 4647
# Keine Überlappung bei: 4648
# Keine Überlappung bei: 4649
# Keine Überlappung bei: 4650
# Keine Überlappung bei: 4651
# Keine Überlappung bei: 4652
# Keine Überlappung bei: 4653
# Keine Überlappung bei: 4654
# Keine Überlappung bei: 4655
# Keine Überlappung bei: 4656
# Keine Überlappung bei: 4657
# Keine Überlappung bei: 4658
# Keine Überlappung bei: 4659
# Keine Überlappung bei: 4660
# Keine Überlappung bei: 4661
# Keine Überlappung bei: 4662
# Keine Überlappung bei: 4663
# Keine Überlappung bei: 4664
# Keine Überlappung bei: 4665
# Keine Überlappung bei: 4666
# Keine Überlappung bei: 4667
# Keine Überlappung bei: 4668
# Keine Überlappung bei: 4669
# Keine Überlappung bei: 4670
# Keine Überlappung bei: 4671
# Keine Überlappung bei: 4672
# Keine Überlappung bei: 4673
# Keine Überlappung bei: 4674
# Keine Überlappung bei: 4675
# Keine Überlappung bei: 4676
# Keine Überlappung bei: 4677
# Keine Überlappung bei: 4678
# Keine Überlappung bei: 4679
# Keine Überlappung bei: 4680
# Keine Überlappung bei: 4681
# Keine Überlappung bei: 4682
# Keine Überlappung bei: 4683
# Keine Überlappung bei: 4684
# Keine Überlappung bei: 4685
# Keine Überlappung bei: 4686
# Keine Überlappung bei: 4687
# Keine Überlappung bei: 4688
# Keine Überlappung bei: 4689
# Keine Überlappung bei: 4690
# Keine Überlappung bei: 4691
# Keine Überlappung bei: 4692
# Keine Überlappung bei: 4693
# Keine Überlappung bei: 4694
# Keine Überlappung bei: 4695
# Keine Überlappung bei: 4696
# Keine Überlappung bei: 4697
# Keine Überlappung bei: 4698
# Keine Überlappung bei: 4699
# Keine Überlappung bei: 4700
# Keine Überlappung bei: 4701
# Keine Überlappung bei: 4702
# Keine Überlappung bei: 4703
# Keine Überlappung bei: 4704
# Keine Überlappung bei: 4705
# Keine Überlappung bei: 4706
# Keine Überlappung bei: 4707
# Keine Überlappung bei: 4708
# Keine Überlappung bei: 4709
# Keine Überlappung bei: 4710
# Keine Überlappung bei: 4711
# Keine Überlappung bei: 4712
# Keine Überlappung bei: 4713
# Keine Überlappung bei: 4714
# Keine Überlappung bei: 4715
# Keine Überlappung bei: 4716
# Keine Überlappung bei: 4717
# Keine Überlappung bei: 4718
# Keine Überlappung bei: 4719
# Keine Überlappung bei: 4720
# Keine Überlappung bei: 4721
# Keine Überlappung bei: 4722
# Keine Überlappung bei: 4723
# Keine Überlappung bei: 4724
# Keine Überlappung bei: 4725
# Keine Überlappung bei: 4726
# Keine Überlappung bei: 4727
# Keine Überlappung bei: 4728
# Keine Überlappung bei: 4729
# Keine Überlappung bei: 4730
# Keine Überlappung bei: 4731
# Keine Überlappung bei: 4732
# Keine Überlappung bei: 4733
# Keine Überlappung bei: 4734
# Keine Überlappung bei: 4735
# Keine Überlappung bei: 4736
# Keine Überlappung bei: 4737
# Keine Überlappung bei: 4738
# Keine Überlappung bei: 4739
# Keine Überlappung bei: 4740
# Keine Überlappung bei: 4741
# Keine Überlappung bei: 4742
# Keine Überlappung bei: 4743
# Keine Überlappung bei: 4744
# Keine Überlappung bei: 4745
# Keine Überlappung bei: 4746
# Keine Überlappung bei: 4747
# Keine Überlappung bei: 4748
# Keine Überlappung bei: 4749
# Keine Überlappung bei: 4750
# Keine Überlappung bei: 4751
# Keine Überlappung bei: 4752
# Keine Überlappung bei: 4753
# Keine Überlappung bei: 4754
# Keine Überlappung bei: 4755
# Keine Überlappung bei: 4756
# Keine Überlappung bei: 4757
# Keine Überlappung bei: 4758
# Keine Überlappung bei: 4759
# Keine Überlappung bei: 4760
# Keine Überlappung bei: 4761
# Keine Überlappung bei: 4762
# Keine Überlappung bei: 4763
# Keine Überlappung bei: 4764
# Keine Überlappung bei: 4765
# Keine Überlappung bei: 4766
# Keine Überlappung bei: 4767
# Keine Überlappung bei: 4768
# Keine Überlappung bei: 4769
# Keine Überlappung bei: 4770
# Keine Überlappung bei: 4771
# Keine Überlappung bei: 4772
# Keine Überlappung bei: 4773
# Keine Überlappung bei: 4774
# Keine Überlappung bei: 4775
# Keine Überlappung bei: 4776
# Keine Überlappung bei: 4777
# Keine Überlappung bei: 4778
# Keine Überlappung bei: 4779
# Keine Überlappung bei: 4780
# Keine Überlappung bei: 4781
# Keine Überlappung bei: 4782
# Keine Überlappung bei: 4783
# Keine Überlappung bei: 4784
# Keine Überlappung bei: 4785
# Keine Überlappung bei: 4786
# Keine Überlappung bei: 4787
# Keine Überlappung bei: 4788
# Keine Überlappung bei: 4789
# Keine Überlappung bei: 4790
# Keine Überlappung bei: 4791
# Keine Überlappung bei: 4792
# Keine Überlappung bei: 4793
# Keine Überlappung bei: 4794
# Keine Überlappung bei: 4795
# Keine Überlappung bei: 4796
# Keine Überlappung bei: 4797
# Keine Überlappung bei: 4798
# Keine Überlappung bei: 4799
# Keine Überlappung bei: 4800
# Keine Überlappung bei: 4801
# Keine Überlappung bei: 4802
# Keine Überlappung bei: 4803
# Keine Überlappung bei: 4804
# Keine Überlappung bei: 4805
# Keine Überlappung bei: 4806
# Keine Überlappung bei: 4808
# Keine Überlappung bei: 4809
# Keine Überlappung bei: 4810
# Keine Überlappung bei: 4811
# Keine Überlappung bei: 4812
# Keine Überlappung bei: 4813
# Keine Überlappung bei: 4814
# Keine Überlappung bei: 4815
# Keine Überlappung bei: 4816
# Keine Überlappung bei: 4817
# Keine Überlappung bei: 4818
# Keine Überlappung bei: 4819
# Keine Überlappung bei: 4820
# Keine Überlappung bei: 4821
# Keine Überlappung bei: 4822
# Keine Überlappung bei: 4823
# Keine Überlappung bei: 4824
# Keine Überlappung bei: 4825
# Keine Überlappung bei: 4826
# Keine Überlappung bei: 4827
# Keine Überlappung bei: 4828
# Keine Überlappung bei: 4829
# Keine Überlappung bei: 4830
# Keine Überlappung bei: 4831
# Keine Überlappung bei: 4832
# Keine Überlappung bei: 4833
# Keine Überlappung bei: 4834
# Keine Überlappung bei: 4835
# Keine Überlappung bei: 4836
# Keine Überlappung bei: 4837
# Keine Überlappung bei: 4838
# Keine Überlappung bei: 4839
# Keine Überlappung bei: 4840
# Keine Überlappung bei: 4841
# Keine Überlappung bei: 4842
# Keine Überlappung bei: 4843
# Keine Überlappung bei: 4844
# Keine Überlappung bei: 4845
# Keine Überlappung bei: 4846
# Keine Überlappung bei: 4847
# Keine Überlappung bei: 4848
# Keine Überlappung bei: 4849
# Keine Überlappung bei: 4850
# Keine Überlappung bei: 4851
# Keine Überlappung bei: 4852
# Keine Überlappung bei: 4853
# Keine Überlappung bei: 4854
# Keine Überlappung bei: 4855
# Keine Überlappung bei: 4856
# Keine Überlappung bei: 4857
# Keine Überlappung bei: 4858
# Keine Überlappung bei: 4859
# Keine Überlappung bei: 4860
# Keine Überlappung bei: 4861
# Keine Überlappung bei: 4862
# Keine Überlappung bei: 4863
# Keine Überlappung bei: 4864
# Keine Überlappung bei: 4865
# Keine Überlappung bei: 4866
# Keine Überlappung bei: 4867
# Keine Überlappung bei: 4868
# Keine Überlappung bei: 4869
# Keine Überlappung bei: 4870
# Keine Überlappung bei: 4871
# Keine Überlappung bei: 4872
# Keine Überlappung bei: 4873
# Keine Überlappung bei: 4874
# Keine Überlappung bei: 4875
# Keine Überlappung bei: 4876
# Keine Überlappung bei: 4877
# Keine Überlappung bei: 4878
# Keine Überlappung bei: 4879
# Keine Überlappung bei: 4880
# Keine Überlappung bei: 4881
# Keine Überlappung bei: 4882
# Keine Überlappung bei: 4883
# Keine Überlappung bei: 4884
# Keine Überlappung bei: 4885
# Keine Überlappung bei: 4886
# Keine Überlappung bei: 4887
# Keine Überlappung bei: 4888
# Keine Überlappung bei: 4889
# Keine Überlappung bei: 4890
# Keine Überlappung bei: 4891
# Keine Überlappung bei: 4892
# Keine Überlappung bei: 4893
# Keine Überlappung bei: 4894
# Keine Überlappung bei: 4895
# Keine Überlappung bei: 4896
# Keine Überlappung bei: 4897
# Keine Überlappung bei: 4898
# Keine Überlappung bei: 4899
# Keine Überlappung bei: 4900
# Keine Überlappung bei: 4901
# Keine Überlappung bei: 4902
# Keine Überlappung bei: 4903
# Keine Überlappung bei: 4904
# Keine Überlappung bei: 4905
# Keine Überlappung bei: 4906
# Keine Überlappung bei: 4907
# Keine Überlappung bei: 4908
# Keine Überlappung bei: 4909
# Keine Überlappung bei: 4910
# Keine Überlappung bei: 4911
# Keine Überlappung bei: 4912
# Keine Überlappung bei: 4913
# Keine Überlappung bei: 4914
# Keine Überlappung bei: 4915
# Keine Überlappung bei: 4916
# Keine Überlappung bei: 4917
# Keine Überlappung bei: 4918
# Keine Überlappung bei: 4919
# Keine Überlappung bei: 4920
# Keine Überlappung bei: 4921
# Keine Überlappung bei: 4922
# Keine Überlappung bei: 4923
# Keine Überlappung bei: 4924
# Keine Überlappung bei: 4925
# Keine Überlappung bei: 4926
# Keine Überlappung bei: 4927
# Keine Überlappung bei: 4928
# Keine Überlappung bei: 4929
# Keine Überlappung bei: 4930
# Keine Überlappung bei: 4931
# Keine Überlappung bei: 4932
# Keine Überlappung bei: 4933
# Keine Überlappung bei: 4934
# Keine Überlappung bei: 4935
# Keine Überlappung bei: 4936
# Keine Überlappung bei: 4937
# Keine Überlappung bei: 4938
# Keine Überlappung bei: 4939
# Keine Überlappung bei: 4940
# Keine Überlappung bei: 4941
# Keine Überlappung bei: 4942
# Keine Überlappung bei: 4943
# Keine Überlappung bei: 4944
# Keine Überlappung bei: 4945
# Keine Überlappung bei: 4946
# Keine Überlappung bei: 4947
# Keine Überlappung bei: 4948
# Keine Überlappung bei: 4949
# Keine Überlappung bei: 4950
# Keine Überlappung bei: 4951
# Keine Überlappung bei: 4952
# Keine Überlappung bei: 4953
# Keine Überlappung bei: 4954
# Keine Überlappung bei: 4955
# Keine Überlappung bei: 4956
# Keine Überlappung bei: 4957
# Keine Überlappung bei: 4958
# Keine Überlappung bei: 4959
# Keine Überlappung bei: 4960
# Keine Überlappung bei: 4961
# Keine Überlappung bei: 4962
# Keine Überlappung bei: 4963
# Keine Überlappung bei: 4964
# Keine Überlappung bei: 4965
# Keine Überlappung bei: 4966
# Keine Überlappung bei: 4967
# Keine Überlappung bei: 4968
# Keine Überlappung bei: 4969
# Keine Überlappung bei: 4970
# Keine Überlappung bei: 4971
# Keine Überlappung bei: 4972
# Keine Überlappung bei: 4973
# Keine Überlappung bei: 4974
# Keine Überlappung bei: 4975
# Keine Überlappung bei: 4976
# Keine Überlappung bei: 4977
# Keine Überlappung bei: 4978
# Keine Überlappung bei: 4979
# Keine Überlappung bei: 4980
# Keine Überlappung bei: 4981
# Keine Überlappung bei: 4982
# Keine Überlappung bei: 4983
# Keine Überlappung bei: 4984
# Keine Überlappung bei: 4985
# Keine Überlappung bei: 4986
# Keine Überlappung bei: 4987
# Keine Überlappung bei: 4988
# Keine Überlappung bei: 4989
# Keine Überlappung bei: 4990
# Keine Überlappung bei: 4991
# Keine Überlappung bei: 4992
# Keine Überlappung bei: 4993
# Keine Überlappung bei: 4994
# Keine Überlappung bei: 4995
# Keine Überlappung bei: 4996
# Keine Überlappung bei: 4998
# Keine Überlappung bei: 4999
# Keine Überlappung bei: 5000
# Keine Überlappung bei: 5001
# Keine Überlappung bei: 5002
# Keine Überlappung bei: 5003
# Keine Überlappung bei: 5004
# Keine Überlappung bei: 5005
# Keine Überlappung bei: 5006
# Keine Überlappung bei: 5007
# Keine Überlappung bei: 5008
# Keine Überlappung bei: 5009
# Keine Überlappung bei: 5010
# Keine Überlappung bei: 5011
# Keine Überlappung bei: 5012
# Keine Überlappung bei: 5013
# Keine Überlappung bei: 5014
# Keine Überlappung bei: 5015
# Keine Überlappung bei: 5016
# Keine Überlappung bei: 5017
# Keine Überlappung bei: 5018
# Keine Überlappung bei: 5019
# Keine Überlappung bei: 5020
# Keine Überlappung bei: 5021
# Keine Überlappung bei: 5022
# Keine Überlappung bei: 5023
# Keine Überlappung bei: 5024
# Keine Überlappung bei: 5025
# Keine Überlappung bei: 5026
# Keine Überlappung bei: 5027
# Keine Überlappung bei: 5028
# Keine Überlappung bei: 5029
# Keine Überlappung bei: 5030
# Keine Überlappung bei: 5031
# Keine Überlappung bei: 5032
# Keine Überlappung bei: 5033
# Keine Überlappung bei: 5034
# Keine Überlappung bei: 5035
# Keine Überlappung bei: 5036
# Keine Überlappung bei: 5037
# Keine Überlappung bei: 5038
# Keine Überlappung bei: 5039
# Keine Überlappung bei: 5040
# Keine Überlappung bei: 5041
# Keine Überlappung bei: 5042
# Keine Überlappung bei: 5043
# Keine Überlappung bei: 5044
# Keine Überlappung bei: 5045
# Keine Überlappung bei: 5046
# Keine Überlappung bei: 5047
# Keine Überlappung bei: 5048
# Keine Überlappung bei: 5049
# Keine Überlappung bei: 5050
# Keine Überlappung bei: 5051
# Keine Überlappung bei: 5052
# Keine Überlappung bei: 5053
# Keine Überlappung bei: 5054
# Keine Überlappung bei: 5055
# Keine Überlappung bei: 5056
# Keine Überlappung bei: 5057
# Keine Überlappung bei: 5058
# Keine Überlappung bei: 5059
# Keine Überlappung bei: 5060
# Keine Überlappung bei: 5061
# Keine Überlappung bei: 5062
# Keine Überlappung bei: 5063
# Keine Überlappung bei: 5064
# Keine Überlappung bei: 5065
# Keine Überlappung bei: 5066
# Keine Überlappung bei: 5067
# Keine Überlappung bei: 5068
# Keine Überlappung bei: 5069
# Keine Überlappung bei: 5070
# Keine Überlappung bei: 5071
# Keine Überlappung bei: 5072
# Keine Überlappung bei: 5073
# Keine Überlappung bei: 5074
# Keine Überlappung bei: 5075
# Keine Überlappung bei: 5076
# Keine Überlappung bei: 5077
# Keine Überlappung bei: 5078
# Keine Überlappung bei: 5079
# Keine Überlappung bei: 5080
# Keine Überlappung bei: 5081
# ...
# Keine Überlappung bei: 63978
# Keine Überlappung bei: 63979
# Keine Überlappung bei: 63980
# Keine Überlappung bei: 63981
# Keine Überlappung bei: 63982
# Keine Überlappung bei: 63983
# Keine Überlappung bei: 63984
# Keine Überlappung bei: 63985
# Keine Überlappung bei: 63986
# Keine Überlappung bei: 63987
# Keine Überlappung bei: 63988
# Keine Überlappung bei: 63989
# Keine Überlappung bei: 63990
# Keine Überlappung bei: 63991
# Keine Überlappung bei: 63992
# Keine Überlappung bei: 63993
# Keine Überlappung bei: 63994
# Keine Überlappung bei: 63995
# Keine Überlappung bei: 63996
# Keine Überlappung bei: 63997
# Keine Überlappung bei: 63998
# Keine Überlappung bei: 63999
# Keine Überlappung bei: 64000
# Keine Überlappung bei: 64001
# Keine Überlappung bei: 64002
# Keine Überlappung bei: 64003
# Keine Überlappung bei: 64004
# Keine Überlappung bei: 64005
# Keine Überlappung bei: 64006
# Keine Überlappung bei: 64007
# Keine Überlappung bei: 64008
# Keine Überlappung bei: 64009
# Keine Überlappung bei: 64010
# Keine Überlappung bei: 64011
# Keine Überlappung bei: 64012
# Keine Überlappung bei: 64013
# Keine Überlappung bei: 64014
# Keine Überlappung bei: 64015
# Keine Überlappung bei: 64016
# Keine Überlappung bei: 64017
# Keine Überlappung bei: 64018
# Keine Überlappung bei: 64019
# Keine Überlappung bei: 64020
# Keine Überlappung bei: 64021
# Keine Überlappung bei: 64022
# Keine Überlappung bei: 64023
# Keine Überlappung bei: 64024
# Keine Überlappung bei: 64025
# Keine Überlappung bei: 64026
# Keine Überlappung bei: 64027
# Keine Überlappung bei: 64028
# Keine Überlappung bei: 64029
# Keine Überlappung bei: 64030
# Keine Überlappung bei: 64031
# Keine Überlappung bei: 64032
# Keine Überlappung bei: 64033
# Keine Überlappung bei: 64034
# Keine Überlappung bei: 64035
# Keine Überlappung bei: 64036
# Keine Überlappung bei: 64037
# Keine Überlappung bei: 64038
# Keine Überlappung bei: 64039
# Keine Überlappung bei: 64040
# Keine Überlappung bei: 64041
# Keine Überlappung bei: 64042
# Keine Überlappung bei: 64043
# Keine Überlappung bei: 64044
# Keine Überlappung bei: 64045
# Keine Überlappung bei: 64046
# Keine Überlappung bei: 64047
# Keine Überlappung bei: 64048
# Keine Überlappung bei: 64049
# Keine Überlappung bei: 64050
# Keine Überlappung bei: 64051
# Keine Überlappung bei: 64052
# Keine Überlappung bei: 64053
# Keine Überlappung bei: 64054
# Keine Überlappung bei: 64055
# Keine Überlappung bei: 64056
# Keine Überlappung bei: 64057
# Keine Überlappung bei: 64058
# Keine Überlappung bei: 64059
# Keine Überlappung bei: 64060
# Keine Überlappung bei: 64061
# Keine Überlappung bei: 64062
# Keine Überlappung bei: 64063
# Keine Überlappung bei: 64064
# Keine Überlappung bei: 64065
# Keine Überlappung bei: 64066
# Keine Überlappung bei: 64067
# Keine Überlappung bei: 64068
# Keine Überlappung bei: 64069
# Keine Überlappung bei: 64070
# Keine Überlappung bei: 64071
# Keine Überlappung bei: 64072
# Keine Überlappung bei: 64073
# Keine Überlappung bei: 64074
# Keine Überlappung bei: 64075
# Keine Überlappung bei: 64076
# Keine Überlappung bei: 64077
# Keine Überlappung bei: 64078
# Keine Überlappung bei: 64079
# Keine Überlappung bei: 64080
# Keine Überlappung bei: 64081
# Keine Überlappung bei: 64082
# Keine Überlappung bei: 64083
# Keine Überlappung bei: 64084
# Keine Überlappung bei: 64085
# Keine Überlappung bei: 64086
# Keine Überlappung bei: 64087
# Keine Überlappung bei: 64088
# Keine Überlappung bei: 64089
# Keine Überlappung bei: 64090
# Keine Überlappung bei: 64091
# Keine Überlappung bei: 64092
# Keine Überlappung bei: 64093
# Keine Überlappung bei: 64094
# Keine Überlappung bei: 64095
# Keine Überlappung bei: 64096
# Keine Überlappung bei: 64097
# Keine Überlappung bei: 64098
# Keine Überlappung bei: 64099
# Keine Überlappung bei: 64100
# Keine Überlappung bei: 64101
# Keine Überlappung bei: 64102
# Keine Überlappung bei: 64103
# Keine Überlappung bei: 64104
# Keine Überlappung bei: 64105
# Keine Überlappung bei: 64106
# Keine Überlappung bei: 64107
# Keine Überlappung bei: 64108
# Keine Überlappung bei: 64109
# Keine Überlappung bei: 64110
# Keine Überlappung bei: 64111
# Keine Überlappung bei: 64112
# Keine Überlappung bei: 64113
# Keine Überlappung bei: 64114
# Keine Überlappung bei: 64115
# Keine Überlappung bei: 64116
# Keine Überlappung bei: 64117
# Keine Überlappung bei: 64118
# Keine Überlappung bei: 64119
# Keine Überlappung bei: 64120
# Keine Überlappung bei: 64121
# Keine Überlappung bei: 64122
# Keine Überlappung bei: 64123
# Keine Überlappung bei: 64124
# Keine Überlappung bei: 64125
# Keine Überlappung bei: 64126
# Keine Überlappung bei: 64127
# Keine Überlappung bei: 64128
# Keine Überlappung bei: 64129
# Keine Überlappung bei: 64130
# Keine Überlappung bei: 64131
# Keine Überlappung bei: 64132
# Keine Überlappung bei: 64133
# Keine Überlappung bei: 64134
# Keine Überlappung bei: 64135
# Keine Überlappung bei: 64136
# Keine Überlappung bei: 64137
# Keine Überlappung bei: 64138
# Keine Überlappung bei: 64139
# Keine Überlappung bei: 64140
# Keine Überlappung bei: 64141
# Keine Überlappung bei: 64142
# Keine Überlappung bei: 64143
# Keine Überlappung bei: 64144
# Keine Überlappung bei: 64145
# Keine Überlappung bei: 64146
# Keine Überlappung bei: 64147
# Keine Überlappung bei: 64148
# Keine Überlappung bei: 64149
# Keine Überlappung bei: 64150
# Keine Überlappung bei: 64151
# Keine Überlappung bei: 64152
# Keine Überlappung bei: 64153
# Keine Überlappung bei: 64154
# Keine Überlappung bei: 64155
# Keine Überlappung bei: 64156
# Keine Überlappung bei: 64157
# Keine Überlappung bei: 64158
# Keine Überlappung bei: 64159
# Keine Überlappung bei: 64160
# Keine Überlappung bei: 64161
# Keine Überlappung bei: 64162
# Keine Überlappung bei: 64163
# Keine Überlappung bei: 64164
# Keine Überlappung bei: 64165
# Keine Überlappung bei: 64166
# Keine Überlappung bei: 64167
# Keine Überlappung bei: 64168
# Keine Überlappung bei: 64169
# Keine Überlappung bei: 64170
# Keine Überlappung bei: 64171
# Keine Überlappung bei: 64172
# Keine Überlappung bei: 64173
# Keine Überlappung bei: 64174
# Keine Überlappung bei: 64175
# Keine Überlappung bei: 64176
# Keine Überlappung bei: 64177
# Keine Überlappung bei: 64178
# Keine Überlappung bei: 64179
# Keine Überlappung bei: 64180
# Keine Überlappung bei: 64182
# Keine Überlappung bei: 64183
# Keine Überlappung bei: 64184
# Keine Überlappung bei: 64185
# Keine Überlappung bei: 64186
# Keine Überlappung bei: 64187
# Keine Überlappung bei: 64188
# Keine Überlappung bei: 64189
# Keine Überlappung bei: 64190
# Keine Überlappung bei: 64191
# Keine Überlappung bei: 64192
# Keine Überlappung bei: 64193
# Keine Überlappung bei: 64194
# Keine Überlappung bei: 64195
# Keine Überlappung bei: 64196
# Keine Überlappung bei: 64197
# Keine Überlappung bei: 64198
# Keine Überlappung bei: 64199
# Keine Überlappung bei: 64200
# Keine Überlappung bei: 64201
# Keine Überlappung bei: 64202
# Keine Überlappung bei: 64203
# Keine Überlappung bei: 64204
# Keine Überlappung bei: 64205
# Keine Überlappung bei: 64206
# Keine Überlappung bei: 64207
# Keine Überlappung bei: 64208
# Keine Überlappung bei: 64209
# Keine Überlappung bei: 64210
# Keine Überlappung bei: 64211
# Keine Überlappung bei: 64212
# Keine Überlappung bei: 64213
# Keine Überlappung bei: 64214
# Keine Überlappung bei: 64215
# Keine Überlappung bei: 64216
# Keine Überlappung bei: 64217
# Keine Überlappung bei: 64218
# Keine Überlappung bei: 64219
# Keine Überlappung bei: 64220
# Keine Überlappung bei: 64221
# Keine Überlappung bei: 64222
# Keine Überlappung bei: 64223
# Keine Überlappung bei: 64224
# Keine Überlappung bei: 64225
# Keine Überlappung bei: 64226
# Keine Überlappung bei: 64227
# Keine Überlappung bei: 64228
# Keine Überlappung bei: 64229
# Keine Überlappung bei: 64230
# Keine Überlappung bei: 64231
# Keine Überlappung bei: 64232
# Keine Überlappung bei: 64233
# Keine Überlappung bei: 64234
# Keine Überlappung bei: 64235
# Keine Überlappung bei: 64236
# Keine Überlappung bei: 64237
# Keine Überlappung bei: 64238
# Keine Überlappung bei: 64239
# Keine Überlappung bei: 64240
# Keine Überlappung bei: 64241
# Keine Überlappung bei: 64242
# Keine Überlappung bei: 64243
# Keine Überlappung bei: 64244
# Keine Überlappung bei: 64245
# Keine Überlappung bei: 64246
# Keine Überlappung bei: 64247
# Keine Überlappung bei: 64248
# Keine Überlappung bei: 64249
# Keine Überlappung bei: 64250
# Keine Überlappung bei: 64251
# Keine Überlappung bei: 64252
# Keine Überlappung bei: 64253
# Keine Überlappung bei: 64254
# Keine Überlappung bei: 64255
# Keine Überlappung bei: 64256
# Keine Überlappung bei: 64257
# Keine Überlappung bei: 64258
# Keine Überlappung bei: 64259
# Keine Überlappung bei: 64260
# Keine Überlappung bei: 64261
# Keine Überlappung bei: 64262
# Keine Überlappung bei: 64263
# Keine Überlappung bei: 64264
# Keine Überlappung bei: 64265
# Keine Überlappung bei: 64266
# Keine Überlappung bei: 64267
# Keine Überlappung bei: 64268
# Keine Überlappung bei: 64269
# Keine Überlappung bei: 64270
# Keine Überlappung bei: 64271
# Keine Überlappung bei: 64272
# Keine Überlappung bei: 64273
# Keine Überlappung bei: 64274
# Keine Überlappung bei: 64275
# Keine Überlappung bei: 64276
# Keine Überlappung bei: 64277
# Keine Überlappung bei: 64278
# Keine Überlappung bei: 64279
# Keine Überlappung bei: 64280
# Keine Überlappung bei: 64281
# Keine Überlappung bei: 64282
# Keine Überlappung bei: 64283
# Keine Überlappung bei: 64284
# Keine Überlappung bei: 64285
# Keine Überlappung bei: 64286
# Keine Überlappung bei: 64287
# Keine Überlappung bei: 64288
# Keine Überlappung bei: 64289
# Keine Überlappung bei: 64290
# Keine Überlappung bei: 64291
# Keine Überlappung bei: 64292
# Keine Überlappung bei: 64293
# Keine Überlappung bei: 64294
# Keine Überlappung bei: 64295
# Keine Überlappung bei: 64296
# Keine Überlappung bei: 64297
# Keine Überlappung bei: 64298
# Keine Überlappung bei: 64299
# Keine Überlappung bei: 64300
# Keine Überlappung bei: 64301
# Keine Überlappung bei: 64302
# Keine Überlappung bei: 64303
# Keine Überlappung bei: 64304
# Keine Überlappung bei: 64305
# Keine Überlappung bei: 64306
# Keine Überlappung bei: 64307
# Keine Überlappung bei: 64308
# Keine Überlappung bei: 64309
# Keine Überlappung bei: 64310
# Keine Überlappung bei: 64311
# Keine Überlappung bei: 64312
# Keine Überlappung bei: 64313
# Keine Überlappung bei: 64314
# Keine Überlappung bei: 64315
# Keine Überlappung bei: 64316
# Keine Überlappung bei: 64317
# Keine Überlappung bei: 64318
# Keine Überlappung bei: 64319
# Keine Überlappung bei: 64320
# Keine Überlappung bei: 64321
# Keine Überlappung bei: 64322
# Keine Überlappung bei: 64323
# Keine Überlappung bei: 64324
# Keine Überlappung bei: 64325
# Keine Überlappung bei: 64326
# Keine Überlappung bei: 64327
# Keine Überlappung bei: 64328
# Keine Überlappung bei: 64329
# Keine Überlappung bei: 64330
# Keine Überlappung bei: 64331
# Keine Überlappung bei: 64332
# Keine Überlappung bei: 64333
# Keine Überlappung bei: 64334
# Keine Überlappung bei: 64335
# Keine Überlappung bei: 64336
# Keine Überlappung bei: 64337
# Keine Überlappung bei: 64338
# Keine Überlappung bei: 64339
# Keine Überlappung bei: 64340
# Keine Überlappung bei: 64341
# Keine Überlappung bei: 64342
# Keine Überlappung bei: 64343
# Keine Überlappung bei: 64344
# Keine Überlappung bei: 64345
# Keine Überlappung bei: 64346
# Keine Überlappung bei: 64347
# Keine Überlappung bei: 64348
# Keine Überlappung bei: 64349
# Keine Überlappung bei: 64350
# Keine Überlappung bei: 64351
# Keine Überlappung bei: 64352
# Keine Überlappung bei: 64353
# Keine Überlappung bei: 64354
# Keine Überlappung bei: 64355
# Keine Überlappung bei: 64356
# Keine Überlappung bei: 64357
# Keine Überlappung bei: 64358
# Keine Überlappung bei: 64359
# Keine Überlappung bei: 64360
# Keine Überlappung bei: 64361
# Keine Überlappung bei: 64362
# Keine Überlappung bei: 64363
# Keine Überlappung bei: 64364
# Keine Überlappung bei: 64365
# Keine Überlappung bei: 64366
# Keine Überlappung bei: 64367
# Keine Überlappung bei: 64368
# Keine Überlappung bei: 64369
# Keine Überlappung bei: 64370
# Keine Überlappung bei: 64371
# Keine Überlappung bei: 64372
# Keine Überlappung bei: 64373
# Keine Überlappung bei: 64374
# Keine Überlappung bei: 64375
# Keine Überlappung bei: 64376
# Keine Überlappung bei: 64377
# Keine Überlappung bei: 64378
# Keine Überlappung bei: 64379
# Keine Überlappung bei: 64380
# Keine Überlappung bei: 64381
# Keine Überlappung bei: 64382
# Keine Überlappung bei: 64383
# Keine Überlappung bei: 64384
# Keine Überlappung bei: 64385
# Keine Überlappung bei: 64386
# Keine Überlappung bei: 64387
# Keine Überlappung bei: 64388
# Keine Überlappung bei: 64389
# Keine Überlappung bei: 64390
# Keine Überlappung bei: 64391
# Keine Überlappung bei: 64392
# Keine Überlappung bei: 64393
# Keine Überlappung bei: 64394
# Keine Überlappung bei: 64395
# Keine Überlappung bei: 64396
# Keine Überlappung bei: 64397
# Keine Überlappung bei: 64398
# Keine Überlappung bei: 64399
# Keine Überlappung bei: 64400
# Keine Überlappung bei: 64401
# Keine Überlappung bei: 64402
# Keine Überlappung bei: 64403
# Keine Überlappung bei: 64404
# Keine Überlappung bei: 64405
# Keine Überlappung bei: 64406
# Keine Überlappung bei: 64407
# Keine Überlappung bei: 64408
# Keine Überlappung bei: 64409
# Keine Überlappung bei: 64410
# Keine Überlappung bei: 64411
# Keine Überlappung bei: 64412
# Keine Überlappung bei: 64413
# Keine Überlappung bei: 64414
# Keine Überlappung bei: 64415
# Keine Überlappung bei: 64416
# Keine Überlappung bei: 64417
# Keine Überlappung bei: 64418
# Keine Überlappung bei: 64419
# Keine Überlappung bei: 64420
# Keine Überlappung bei: 64421
# Keine Überlappung bei: 64422
# Keine Überlappung bei: 64423
# Keine Überlappung bei: 64424
# Keine Überlappung bei: 64425
# Keine Überlappung bei: 64426
# Keine Überlappung bei: 64427
# Keine Überlappung bei: 64428
# Keine Überlappung bei: 64429
# Keine Überlappung bei: 64430
# Keine Überlappung bei: 64431
# Keine Überlappung bei: 64432
# Keine Überlappung bei: 64433
# Keine Überlappung bei: 64434
# Keine Überlappung bei: 64435
# Keine Überlappung bei: 64436
# Keine Überlappung bei: 64437
# Keine Überlappung bei: 64438
# Keine Überlappung bei: 64439
# Keine Überlappung bei: 64440
# Keine Überlappung bei: 64441
# Keine Überlappung bei: 64442
# Keine Überlappung bei: 64443
# Keine Überlappung bei: 64444
# Keine Überlappung bei: 64445
# Keine Überlappung bei: 64446
# Keine Überlappung bei: 64447
# Keine Überlappung bei: 64448
# Keine Überlappung bei: 64449
# Keine Überlappung bei: 64450
# Keine Überlappung bei: 64451
# Keine Überlappung bei: 64452
# Keine Überlappung bei: 64453
# Keine Überlappung bei: 64454
# Keine Überlappung bei: 64455
# Keine Überlappung bei: 64456
# Keine Überlappung bei: 64457
# Keine Überlappung bei: 64458
# Keine Überlappung bei: 64459
# Keine Überlappung bei: 64460
# Keine Überlappung bei: 64461
# Keine Überlappung bei: 64462
# Keine Überlappung bei: 64463
# Keine Überlappung bei: 64464
# Keine Überlappung bei: 64465
# Keine Überlappung bei: 64466
# Keine Überlappung bei: 64467
# Keine Überlappung bei: 64468
# Keine Überlappung bei: 64469
# Keine Überlappung bei: 64470
# Keine Überlappung bei: 64471
# Keine Überlappung bei: 64472
# Keine Überlappung bei: 64473
# Keine Überlappung bei: 64474
# Keine Überlappung bei: 64475
# Keine Überlappung bei: 64476
# Keine Überlappung bei: 64477
# Keine Überlappung bei: 64478
# Keine Überlappung bei: 64479
# Keine Überlappung bei: 64480
# Keine Überlappung bei: 64481
# Keine Überlappung bei: 64483
# Keine Überlappung bei: 64484
# Keine Überlappung bei: 64485
# Keine Überlappung bei: 64486
# Keine Überlappung bei: 64487
# Keine Überlappung bei: 64488
# Keine Überlappung bei: 64489
# Keine Überlappung bei: 64490
# Keine Überlappung bei: 64491
# Keine Überlappung bei: 64492
# Keine Überlappung bei: 64493
# Keine Überlappung bei: 64494
# Keine Überlappung bei: 64495
# Keine Überlappung bei: 64496
# Keine Überlappung bei: 64497
# Keine Überlappung bei: 64498
# Keine Überlappung bei: 64499
# Keine Überlappung bei: 64500
# Keine Überlappung bei: 64501
# Keine Überlappung bei: 64502
# Keine Überlappung bei: 64503
# Keine Überlappung bei: 64504
# Keine Überlappung bei: 64505
# Keine Überlappung bei: 64506
# Keine Überlappung bei: 64507
# Keine Überlappung bei: 64508
# Keine Überlappung bei: 64509
# Keine Überlappung bei: 64510
# Keine Überlappung bei: 64511
# Keine Überlappung bei: 64512
# Keine Überlappung bei: 64513
# Keine Überlappung bei: 64514
# Keine Überlappung bei: 64515
# Keine Überlappung bei: 64516
# Keine Überlappung bei: 64517
# Keine Überlappung bei: 64518
# Keine Überlappung bei: 64519
# Keine Überlappung bei: 64520
# Keine Überlappung bei: 64521
# Keine Überlappung bei: 64522
# Keine Überlappung bei: 64523
# Keine Überlappung bei: 64524
# Keine Überlappung bei: 64525
# Keine Überlappung bei: 64526
# Keine Überlappung bei: 64527
# Keine Überlappung bei: 64528
# Keine Überlappung bei: 64529
# Keine Überlappung bei: 64530

# %%
# Nur Text und Label werden in 'compare' gespeichert:
d = {'pred_new': twit_comp_new, 'text_new': twit_text_new, 'pred_old': twit_comp_old, 'text_old': twit_text_old}
compare = pd.DataFrame(d)
pickle.dump(compare, open(Path + 'compare_old_new_label.p', "wb" ))

# Speichere DataFrame als csv in dem NUR die nicht gleichen predictions aus old und new stehen:
# compare_no_match = compare[compare['pred_new'] != compare['pred_old']][['text_old', 'pred_old', 'pred_new']]
# compare_no_match.to_csv('/home/lisa/Darmstadt/Master Arbeit/06_Analyse/more_train.csv',sep='\t', header = False, index = False)

# Speichere DataFrame als csv in dem NUR die OFFENSE predictions aus old und new stehen:
compare_OFFENSE = compare.loc[(compare['pred_new'] == 'OFFENSE') &
                               (compare['pred_old'] == 'OFFENSE')][['text_old', 'pred_old', 'pred_new']]
compare_no_match.to_csv('/home/lisa/Darmstadt/Master Arbeit/06_Analyse/more_train_OFFENSE.csv',sep='\t', header = False, index = False)

# Speichere DataFrame als csv in dem NUR die OTHER predictions aus old und new stehen:
compare_OTHER = compare.loc[(compare['pred_new'] == 'OTHER') &
                               (compare['pred_old'] == 'OTHER')][['text_old', 'pred_old', 'pred_new']]
compare_no_match.to_csv(Path + 'more_train_OTHER.csv',sep='\t', header = False, index = False)

# %%
import random
# Speichere DataFrame als csv in dem NUR die OFFENSE predictions aus old und new stehen:
compare_OTHER = compare.loc[(compare['pred_new'] == 'OTHER') &
                               (compare['pred_old'] == 'OTHER')][['text_old', 'pred_old', 'pred_new']]

compare_OTHER_sample = random.sample(list(compare_OTHER.index), 1000)
comp_OTHER_samp = compare_OTHER.loc[compare_OTHER_sample]
comp_OTHER_samp.to_csv(Path + 'comp_OTHER_samp.csv',sep='\t', header = False, index = False)

compare_OFFENSE = compare.loc[(compare['pred_new'] == 'OFFENSE') &
                               (compare['pred_old'] == 'OFFENSE')][['text_old', 'pred_old', 'pred_new']]

compare_OFFENSE_sample = random.sample(list(compare_OFFENSE.index), 100)
comp_OFFENSE_samp = compare_OFFENSE.loc[compare_OFFENSE_sample]
comp_OFFENSE_samp.to_csv(Path + 'comp_OFFENSE_samp.csv',sep='\t', header = False, index = False)

# 8540 (GermEval)
# 708 (No_match)
# 100 (OFFENSE) -> nicht nur OFFENSE - Korrektur von ca 10 Tweets
# 994 (OTHER) -> nicht nur OTHER

# %% [markdown]
# ## Lade neu-erstellten Gesamtdatensatz und teile ihn in Test und Train Satz auf

# %%
from utilities import get_train_data, get_test_data, Tokenizer, find_subtoken
train_imp = get_train_data(Path + 'germeval2018.train_imp.txt')
train = {'Text': train_imp[0], 'Label': train_imp[1], 'other_label': train_imp[2]} 
df_more_train = pd.DataFrame(train)

# %%
import random
df_imp_train_rand = random.sample(list(df_more_train.index), 3000)

## TEST ## (3000)
test_rand = df_more_train.loc[df_imp_train_rand]
test_rand.to_csv(Path + 'germEval_test_rand.txt',sep='\t', header = False, index = False)

## TRAIN ## (7343)
more_train = df_more_train.loc[~df_more_train.index.isin(df_imp_train_rand)]
more_train.to_csv(Path + 'germEvalmore_train.txt',sep='\t', header = False, index = False)

# %%
import pandas as pd
# Ealuierung muss vergleichbar sein -> deshalb zweiter Versuch:

Eval_Path = '/home/lisa/Darmstadt/Master Arbeit/06_Analyse/Evaluierung/'

# Train1 ist GermEval Test+Train Set (8541 Zeilen)
# Train2 ist GermEval Test+Train + random Sample von 1000 aus Eval_Test_New (1802 Zeilen)
# Test bei beiden Eval_Test_New (1802 Zeilen) - 1000 random sample

##### 1.) Erstelle Random Sample
from utilities import get_train_data, get_test_data, Tokenizer, find_subtoken
Eval_New_Label = get_train_data(Eval_Path + 'Eval_Test_new_1802.txt')
data = {'Text': Eval_New_Label[0], 'Label': Eval_New_Label[1], 'other_label': Eval_New_Label[2]} 
df_more_data = pd.DataFrame(data)

# %%
import random
df_imp_data_rand = random.sample(list(df_more_data.index), 1000) # Random sample index

## Mehr Training ## (1000)
data_rand = df_more_data.loc[df_imp_data_rand] # Zu Index gehörige Daten - random
data_rand.to_csv(Eval_Path + 'self_label_train_1000.txt',sep='\t', header = False, index = False)

## Test ## (802)
test = df_more_data.loc[~df_more_data.index.isin(df_imp_data_rand)]
test.to_csv(Eval_Path + 'self_label_test_802.txt',sep='\t', header = False, index = False)

# %% [markdown]
# ## Accuracy,  Prediction, Recall, F1

# %% [markdown]
# #### Stufen der Klassifizierung:
# * Ganz am Anfang nur mit dem Trainingsdatensatz von Germ Eval (Bereits erste Graischen Analysen usw)
# * Dann mit dem Tranings UND Test Datensatz von GermEval (Einige Klassifiziert - mit dem Ziel Verbesserung zu schaffen)
# * Zum Evaluieren - Training mit random select Trainingsdatensatz
# * Final: Trainiere mit allen gelabelten Daten

# %%
# Evaluiere mit random train/test Kombbi
# Ergebnisse vermutlich beser als bei Test NUR mit mdp Tweets weil viele der GermEval Tweets in Train und Test Set sind
test_imp = pickle.load(open(Path + 'pickle_TU_Wien/test_imp.p', "rb" )) 
test_imp.columns
testy = test_imp['Label']
yhat_classes = test_imp['predict']

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

#accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(testy, yhat_classes)
print('Accuracy: %f' % accuracy)

#precision tp / (tp + fp)
precision_OF = precision_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
precision_OT = precision_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('Precision: %f' % precision_OF)
print('Precision: %f' % precision_OT)

# recall: tp / (tp + fn)
recall_OF = recall_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
recall_OT = recall_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('Recall: %f' % recall_OF)
print('Recall: %f' % recall_OT)

# f1: 2 tp / (2 tp + fp + fn)
f1_OF = f1_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
f1_OT = f1_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('F1 score: %f' % f1_OF)
print('F1 score: %f' % f1_OT)
# Out:
# Accuracy: 0.806333
# Precision: 0.674667
# Precision: 0.885333
# Recall: 0.779261
# Recall: 0.819348
# F1 score: 0.723202
# F1 score: 0.851064

# %%
# Trainiert mit ganzem GermEval Set
# Evaluiert mit allen händisch korrigierten Tweets
# Vmtl. schlechter als jetzt 1.) Weil nachtrainiert mit Politiker Tweets
#                            2.) Weil ca 700 Tweets genau die schwer zu klassifizierenden Tweets waren

from utilities import get_train_data, get_test_data, Tokenizer, find_subtoken
Eval_Test_new = get_train_data(Path + 'Eval_Test_new.txt')
test_new = {'Text': Eval_Test_new[0], 'y': Eval_Test_new[1], 'y_hat': Eval_Test_new[2]} 
df_test_new = pd.DataFrame(test_new)

testy = df_test_new['y']
yhat_classes = df_test_new['y_hat']

# %%
#accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(testy, yhat_classes)
print('Accuracy: %f' % accuracy)

#precision tp / (tp + fp)
precision_OF = precision_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
precision_OT = precision_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('Precision: %f' % precision_OF)
print('Precision: %f' % precision_OT)

# recall: tp / (tp + fn)
recall_OF = recall_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
recall_OT = recall_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('Recall: %f' % recall_OF)
print('Recall: %f' % recall_OT)

# f1: 2 tp / (2 tp + fp + fn)
f1_OF = f1_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
f1_OT = f1_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('F1 score: %f' % f1_OF)
print('F1 score: %f' % f1_OT)
# Out:
# Accuracy: 0.735294
# Precision: 0.581395
# Precision: 0.783528
# Recall: 0.457038
# Recall: 0.856574
# F1 score: 0.511771
# F1 score: 0.818424

# %%
import pickle, gensim, numpy as np

# Trainiert mit ganzem GermEval Set
# Evaluiert mit 802 händisch korrigierten Tweets

test_imp = pickle.load(open(Eval_Path + 'Eval_1.p', "rb" )) 
test_imp.columns
testy = test_imp['Label']
yhat_classes = test_imp['predict']


#Accuracy: 0.746883
#Precision_OF: 0.606061
#Precision_OT: 0.793046
#Recall_OF: 0.489796
#Recall_OT: 0.859964
#F1 score_OF: 0.541761
#F1 score_OT: 0.825151

# %%
# Trainiert mit ganzem GermEval Set + 1000 selbst gelabelten
# Evaluiert mit 802 händisch korrigierten Tweets

test_imp = pickle.load(open(Eval_Path + 'Eval_2.p', "rb" )) 
test_imp.columns
testy = test_imp['Label']
yhat_classes = test_imp['predict']

#Accuracy: 0.807980
#Precision_OF: 0.693617
#Precision_OT: 0.855379
#Recall_OF: 0.665306
#Recall_OT: 0.870736
#F1 score_OF: 0.679167
F1 score_OT: 0.862989

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

#accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(testy, yhat_classes)
print('Accuracy: %f' % accuracy)

#precision tp / (tp + fp)
precision_OF = precision_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
precision_OT = precision_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('Precision_OF: %f' % precision_OF)
print('Precision_OT: %f' % precision_OT)

# recall: tp / (tp + fn)
recall_OF = recall_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
recall_OT = recall_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('Recall_OF: %f' % recall_OF)
print('Recall_OT: %f' % recall_OT)

# f1: 2 tp / (2 tp + fp + fn)
f1_OF = f1_score(testy, yhat_classes, average="binary", pos_label="OFFENSE")
f1_OT = f1_score(testy, yhat_classes, average="binary", pos_label="OTHER")
print('F1 score_OF: %f' % f1_OF)
print('F1 score_OT: %f' % f1_OT)
